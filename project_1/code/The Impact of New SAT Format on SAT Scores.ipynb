# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def mean(list_values):
    '''Returns the mean (float) from a list of values'''
    
    return sum(list_values) / len(list_values)

# %%
mean([600,470,170,430,300])
# Out:
# 394.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def variance(list_values):
    '''Returns the average of the squared difference from the mean '''
    return mean([(x - mean(list_values)) ** 2 for x in list_values])

def standev(list_values):
    
    return (variance(list_values) ** (1/2))

# %%
standev([600,470,170,430,300])
# Out:
# 147.32277488562318

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def string_to_float(s):
    '''
    converts data from string to float type
    if it is not a string type, it would skip
    '''
    try:   #if parameter is already a float type, to skip to except block
        number = s.strip('%')
        percentage = float(number) / 100
        return percentage
    except TypeError:
        return s

print(string_to_float('30.5%'))
print(string_to_float('50%'))
# Out:
# 0.305
# 0.5

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ## 2017 Data

# %% [markdown]
# ### Read the datasets

# %%
# Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# ### 1. Display the data

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# ### 2. Check for missing values

# %%
# 2. Check for missing values. 
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Answer: There are no missing values

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
sat_2017.describe()
# the min for SAT math score looks unusually low
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017[~sat_2017['Math'].between(200, 800)]
# Maryland's Math score shouldn't be below 200
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
act_2017.describe()
# the min for science score looks unusually low
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# 1. For SAT, the minimum and maximum scores for each test/subtest is 200 and 800
# 2. For ACT, the minimum and maximum scores for each test/subtest is 1 and 36
# 3. For ACT, the composite score for Wyoming (index 51) is "20.2x", which will be an issue when analyzing score
# 4. For SAT, Maryland's math score of 52 looks unusually low. Upon checking the source, the score should be 524 instead
# 5. Based on observation, for ACT, Maryland's science score of 2.3 looks unusually low. Upon checking the source, the score should be 23.1 instead

# %% [markdown]
# ### 4 .Fix any errors you identified in steps 2-3.

# %%
# fixing act_2017 data for Wyoming's composite score

act_2017.loc[act_2017['State'] == 'Wyoming', 'Composite'] = 20.2
act_2017.loc[act_2017['State'] == 'Wyoming', 'Composite']
# Out:
# 51    20.2
# Name: Composite, dtype: object

# %%
# fixing sat_2017 data for Maryland's math score

sat_2017.loc[sat_2017['State'] == 'Maryland', 'Math'] = 524
sat_2017.loc[sat_2017['State'] == 'Maryland', 'Math']
# Out:
# 20    524
# Name: Math, dtype: int64

# %%
# fixing act_2017 data for Maryland's math score

act_2017.loc[act_2017['State'] == 'Maryland', 'Science'] = 23.1
act_2017.loc[act_2017['State'] == 'Maryland', 'Science']
# Out:
# 21    23.1
# Name: Science, dtype: float64

# %% [markdown]
# ### 5. Display the data types of each feature.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# ### 6. Fix any incorrect data types found in step 5.
# Fix any individual values preventing other columns from being the appropriate type.
# If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! Hint: use .map() or .apply().

# %% [markdown]
# Answer:
# 1. For SAT: The participation rate is in string format, which should be in numerical format.
# 2. For ACT: The participation rate and composite score is in string format, which should be in numerical format.

# %%
# Fix SAT 'Participation' data type to float
sat_2017.loc[:, 'Participation'] = sat_2017.loc[:, 'Participation'].apply(string_to_float)
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# Fix ACT 'Participation' data type to float
act_2017.loc[:, 'Participation'] = act_2017.loc[:, 'Participation'].apply(string_to_float)
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB

# %%
# Fix ACT 'Composite' data type to float
act_2017.loc[:, 'Composite'] = act_2017.loc[:, 'Composite'].apply(lambda x: float(x))
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# ### 7. Rename Columns.
# Column names should be all lowercase.
# Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name']).
# Column names should be unique and informative.

# %%
# SAT: change column names to be all lowercase
# also change the column names to indicate that data is from SAT since we are merging 2017 & 2018's SAT and ACT data

sat_2017.rename(columns = {'State': 'state',
                           'Participation': '2017_sat_participation',
                           'Evidence-Based Reading and Writing': '2017_sat_read_write',
                           'Math': '2017_sat_math',
                           'Total': '2017_sat_total'}, inplace=True)

sat_2017.columns
# Out:
# Index(['state', '2017_sat_participation', '2017_sat_read_write',
#        '2017_sat_math', '2017_sat_total'],
#       dtype='object')

# %%
# ACT: change column names to be all lowercase
# also change the column names to indicate that data is from ACT since we are merging 2017 & 2018's SAT and ACT data

act_2017.rename(columns = {'State': 'state',
                           'Participation': '2017_act_participation',
                           'English': '2017_act_english',
                           'Math': '2017_act_math',
                           'Reading': '2017_act_reading',
                           'Science': '2017_act_science',
                           'Composite': '2017_act_composite'}, inplace=True)

act_2017.columns
# Out:
# Index(['state', '2017_act_participation', '2017_act_english', '2017_act_math',
#        '2017_act_reading', '2017_act_science', '2017_act_composite'],
#       dtype='object')

# %% [markdown]
# ### 8. Drop unnecessary rows (if needed).

# %%
# drop row 0 (National row) on act_2017 so that we can subsequently merge with sat_2017
act_2017.drop([0], axis=0, inplace=True)

# %%
#reset the index for act_2017
act_2017.reset_index(drop=True, inplace=True)

# %%
act_2017.head()
# Out:
#         state  2017_act_participation  2017_act_english  2017_act_math  \
# 0     Alabama                    1.00              18.9           18.4
# 1      Alaska                    0.65              18.7           19.8
# 2     Arizona                    0.62              18.6           19.8
# 3    Arkansas                    1.00              18.9           19.0
# 4  California                    0.31              22.5           22.7
#
#    2017_act_reading  2017_act_science  2017_act_composite
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8

# %% [markdown]
# ### 9. Merge dataframes that can be merged.

# %%
# merge both sat_2017 and act_2017 to a new df 'sat_act_2017' using 'state' column as the key
sat_act_2017 = pd.merge(sat_2017, act_2017, how = 'outer', on = 'state')
# sat_act_2017

# %%
sat_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   2017_sat_participation  51 non-null     float64
#  2   2017_sat_read_write     51 non-null     int64
#  3   2017_sat_math           51 non-null     int64
#  4   2017_sat_total          51 non-null     int64
#  5   2017_act_participation  51 non-null     float64
#  6   2017_act_english        51 non-null     float64
#  7   2017_act_math           51 non-null     float64
#  8   2017_act_reading        51 non-null     float64
#  9   2017_act_science        51 non-null     float64
#  10  2017_act_composite      51 non-null     float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# ### 10. Save your cleaned and merged dataframes as csv files.

# %%
# output processing: create new csv file named sat_act_2017
sat_act_2017.to_csv('../data/sat_act_2017.csv')

# %%
sat_act_2017
# Out:
#                    state  2017_sat_participation  2017_sat_read_write  \
# 0                Alabama                    0.05                  593
# 1                 Alaska                    0.38                  547
# 2                Arizona                    0.30                  563
# 3               Arkansas                    0.03                  614
# 4             California                    0.53                  531
# 5               Colorado                    0.11                  606
# 6            Connecticut                    1.00                  530
# 7               Delaware                    1.00                  503
# 8   District of Columbia                    1.00                  482
# 9                Florida                    0.83                  520
# 10               Georgia                    0.61                  535
# 11                Hawaii                    0.55                  544
# ...

# %% [markdown]
# ## 2018 data

# %% [markdown]
# ### Read the data

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %% [markdown]
# ### 1. Display the data

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# ### 2. Check for missing values

# %%
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# Answer: There are no missing values for both datasets

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# there are 52 rows for this dataset, compared to 51 rows for the others
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2018
# there is a duplicate row for the state of Maine
# let us also make the spelling of District of Columbia uniform by amending the 'c' to capital 'C'
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %% [markdown]
# Answer:
# 1. Maine was repeated twice in act_2018 (index 19 and 20). We will drop one of the rows
# 2. Some minor adjustment on spelling for state name: District of Columbia on index 8 with capital 'C'

# %% [markdown]
# ### 4. Fix any errors you identified in steps 2-3.

# %%
# Maine is repeated twice in index 19 and 20, to remove duplicated row
act_2018.drop([20], axis=0, inplace=True)

# %%
# reset the index for act_2018
act_2018.reset_index(drop=True, inplace=True)

# %%
# Fix act_2018's state name of 'District of columbia' on index 8 to 'District of columbia' with capital C
act_2018.loc[act_2018['State'] == 'District of columbia', 'State'] = 'District of Columbia'

# %%
act_2018.loc[act_2018['State'] == 'District of Columbia', 'State']
# Out:
# 8    District of Columbia
# Name: State, dtype: object

# %% [markdown]
# ### 5. Display the data types of each feature.

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# ### 6. Fix any incorrect data types found in step 5.

# %% [markdown]
# Answer:
#
# For the 'Participation' column should be in numerical format for both sat_2018 and act_2018

# %%
# Fix ACT 'Participation' data type to float
act_2018.loc[:, 'Participation'] = act_2018.loc[:, 'Participation'].apply(string_to_float)
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     float64
#  2   Composite      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
# Fix SAT 'Participation' data type to float
sat_2018.loc[:, 'Participation'] = sat_2018.loc[:, 'Participation'].apply(string_to_float)
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ### 7. Rename Columns.

# %%
# for act_2018, rename columns to lowercase and give proper distinction to differentiate columns after merging

act_2018.rename(columns = {'State': 'state',
                           'Participation': '2018_act_participation',
                           'Composite': '2018_act_composite'}, inplace=True)
act_2018.columns
# Out:
# Index(['state', '2018_act_participation', '2018_act_composite'], dtype='object')

# %%
# do the same for sat_2018 as well

sat_2018.rename(columns = {'State': 'state',
                           'Participation': '2018_sat_participation',
                           'Evidence-Based Reading and Writing': '2018_sat_read_write',
                           'Math': '2018_sat_math',
                           'Total': '2018_sat_total'}, inplace=True)
sat_2018.columns
# Out:
# Index(['state', '2018_sat_participation', '2018_sat_read_write',
#        '2018_sat_math', '2018_sat_total'],
#       dtype='object')

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   2018_act_participation  51 non-null     float64
#  2   2018_act_composite      51 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   2018_sat_participation  51 non-null     float64
#  2   2018_sat_read_write     51 non-null     int64
#  3   2018_sat_math           51 non-null     int64
#  4   2018_sat_total          51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ### 8. Drop unnecessary rows (if needed).

# %% [markdown]
# Answer: We had already dropped the duplicated row of Maine

# %% [markdown]
# ### 9. Merge dataframes that can be merged.

# %%
# merge both sat_2018 and act_2018 to a new df 'sat_act_2018' using 'state' column as the key
sat_act_2018 = pd.merge(sat_2018, act_2018, how='outer', on='state')
sat_act_2018
# Out:
#                    state  2018_sat_participation  2018_sat_read_write  \
# 0                Alabama                    0.06                  595
# 1                 Alaska                    0.43                  562
# 2                Arizona                    0.29                  577
# 3               Arkansas                    0.05                  592
# 4             California                    0.60                  540
# 5               Colorado                    1.00                  519
# 6            Connecticut                    1.00                  535
# 7               Delaware                    1.00                  505
# 8   District of Columbia                    0.92                  497
# 9                Florida                    0.56                  550
# 10               Georgia                    0.70                  542
# 11                Hawaii                    0.56                  480
# ...

# %%
sat_act_2018[['state', '2018_sat_participation', '2018_sat_total']].sort_values(by='2018_sat_total', ascending=False)
# Out:
#                    state  2018_sat_participation  2018_sat_total
# 23             Minnesota                    0.04            1298
# 49             Wisconsin                    0.03            1294
# 34          North Dakota                    0.02            1283
# 15                  Iowa                    0.03            1265
# 16                Kansas                    0.04            1265
# 25              Missouri                    0.04            1262
# 50               Wyoming                    0.03            1257
# 27              Nebraska                    0.03            1252
# 17              Kentucky                    0.04            1248
# 41          South Dakota                    0.03            1240
# 24           Mississippi                    0.03            1236
# 42             Tennessee                    0.06            1231
# 18             Louisiana                    0.04            1210
# ...

# %%
sat_act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   2018_sat_participation  51 non-null     float64
#  2   2018_sat_read_write     51 non-null     int64
#  3   2018_sat_math           51 non-null     int64
#  4   2018_sat_total          51 non-null     int64
#  5   2018_act_participation  51 non-null     float64
#  6   2018_act_composite      51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ### 10. Save your cleaned and merged dataframes as csv files.

# %%
# output processing: create new csv file named sat_act_2018
sat_act_2018.to_csv('../data/sat_act_2018.csv')

# %% [markdown]
# ### We shall combine both 2017 and 2018 data together to a final dataframe

# %%
final = pd.merge(sat_act_2017, sat_act_2018, how='outer', on='state')
final.to_csv('../data/final.csv')
final.tail()
# Out:
#             state  2017_sat_participation  2017_sat_read_write  2017_sat_math  \
# 46       Virginia                    0.65                  561            541
# 47     Washington                    0.64                  541            534
# 48  West Virginia                    0.14                  558            528
# 49      Wisconsin                    0.03                  642            649
# 50        Wyoming                    0.03                  626            604
#
#     2017_sat_total  2017_act_participation  2017_act_english  2017_act_math  \
# 46            1102                    0.29              23.5           23.3
# 47            1075                    0.29              20.9           21.9
# 48            1086                    0.69              20.0           19.4
# 49            1291                    1.00              19.7           20.4
# 50            1230                    1.00              19.4           19.8
#
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   2017_sat_participation  51 non-null     float64
#  2   2017_sat_read_write     51 non-null     int64
#  3   2017_sat_math           51 non-null     int64
#  4   2017_sat_total          51 non-null     int64
#  5   2017_act_participation  51 non-null     float64
#  6   2017_act_english        51 non-null     float64
#  7   2017_act_math           51 non-null     float64
#  8   2017_act_reading        51 non-null     float64
#  9   2017_act_science        51 non-null     float64
#  10  2017_act_composite      51 non-null     float64
#  11  2018_sat_participation  51 non-null     float64
#  12  2018_sat_read_write     51 non-null     int64
#  13  2018_sat_math           51 non-null     int64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|
#
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat_2017.csv|Name of the state|
# |2017_sat_participation|float64|sat_2017.csv|SAT 2017 participation rate|
# |2017_sat_read_write|float64|sat_2017.csv|SAT 2017 Evidence-Based Reading and Writing Score|
# |2017_sat_math|float64|sat_2017.csv|SAT 2017 Math Score|
# |2017_sat_total|float64|sat_2017.csv|SAT 2017 Total Score|
# |2017_act_participation|float64|sat_2017.csv|ACT 2017 participation rate|
# |2017_act_english|float64|act_2017.csv|ACT 2017 English Score|
# |2017_act_math|float64|act_2017.csv|ACT 2017 Math Score|
# |2017_act_reading|float64|act_2017.csv|ACT 2017 Reading Score|
# |2017_act_science|float64|act_2017.csv|ACT 2017 Science Score|
# |2017_act_composite|float64|act_2017.csv|ACT 2017 Composite Score|
# |2018_sat_participation|float64|sat_2018.csv|SAT 2018 participation rate|
# |2018_sat_read_write|float64|sat_2018.csv|SAT 2018 Evidence-Based Reading and Writing Score|
# |2018_sat_math|float64|sat_2018.csv|SAT 2018 Math Score|
# |2018_sat_total|float64|sat_2018.csv|SAT 2018 Total Score|
# |2018_act_participation|float64|act_2018.csv|ACT 2018 participation rate|
# |2018_act_composite|float64|act_2017.csv|ACT 2018 Composite Score|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
final.describe()
# Out:
#        2017_sat_participation  2017_sat_read_write  2017_sat_math  \
# count               51.000000            51.000000      51.000000
# mean                 0.398039           569.117647     556.882353
# std                  0.352766            45.666901      47.121395
# min                  0.020000           482.000000     468.000000
# 25%                  0.040000           533.500000     523.500000
# 50%                  0.380000           559.000000     548.000000
# 75%                  0.660000           613.000000     599.000000
# max                  1.000000           644.000000     651.000000
#
#        2017_sat_total  2017_act_participation  2017_act_english  \
# count       51.000000               51.000000         51.000000
# mean      1126.098039                0.652549         20.931373
# std         92.494812                0.321408          2.353677
# min        950.000000                0.080000         16.300000
# ...

# %%
final.mean()
# Out:
# 2017_sat_participation       0.398039
# 2017_sat_read_write        569.117647
# 2017_sat_math              556.882353
# 2017_sat_total            1126.098039
# 2017_act_participation       0.652549
# 2017_act_english            20.931373
# 2017_act_math               21.182353
# 2017_act_reading            22.013725
# 2017_act_science            21.449020
# 2017_act_composite          21.519608
# 2018_sat_participation       0.457451
# 2018_sat_read_write        563.686275
# 2018_sat_math              556.235294
# 2018_sat_total            1120.019608
# 2018_act_participation       0.617255
# 2018_act_composite          21.496078
# dtype: float64

# %% [markdown]
# Key observations:
# 1. mean participation rates for ACT tests in general is much higher than SAT tests
# 2. For the period of 2017 and 2018, we saw an increase for mean participation rates for SAT but decrease for ACT
# 3. For the period of 2017 and 2018, the mean SAT and ACT scores remained relatively the same

# %% [markdown]
# ### 2. Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe

# %%
sd = {column: standev(final.loc[:, column]) for column in final.columns if column != 'state'}

# %%
sd
# Out:
# {'2017_sat_participation': 0.3492907076664507,
#  '2017_sat_read_write': 45.21697020437866,
#  '2017_sat_math': 46.65713364485503,
#  '2017_sat_total': 91.58351056778743,
#  '2017_act_participation': 0.3182417575123181,
#  '2017_act_english': 2.3304876369363363,
#  '2017_act_math': 1.9624620273436781,
#  '2017_act_reading': 2.0469029314842646,
#  '2017_act_science': 1.7202795656314875,
#  '2017_act_composite': 2.000786081581989,
#  '2018_sat_participation': 0.3694661922353942,
#  '2018_sat_read_write': 47.03460978357609,
#  '2018_sat_math': 47.30194550378352,
#  '2018_sat_total': 93.22742384464433,
#  '2018_act_participation': 0.33701735820410317,
#  '2018_act_composite': 2.090779082141178}

# %% [markdown]
# ### 3. Investigate trends in the data.

# %% [markdown]
# Which states have the highest and lowest participation rates for the 2017, 2018 SAT and ACT?

# %%
# SAT top participation rates for 2017

final[['state', '2017_sat_participation', '2018_sat_participation']].sort_values(by='2017_sat_participation', ascending=False).head()
# Out:
#                    state  2017_sat_participation  2018_sat_participation
# 8   District of Columbia                    1.00                    0.92
# 22              Michigan                    1.00                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 29         New Hampshire                    0.96                    0.96

# %%
# SAT lowest participation rates for 2017

final[['state', '2017_sat_participation', '2018_sat_participation']].sort_values(by='2017_sat_participation', ascending=True).head()
# Out:
#            state  2017_sat_participation  2018_sat_participation
# 34  North Dakota                    0.02                    0.02
# 24   Mississippi                    0.02                    0.03
# 15          Iowa                    0.02                    0.03
# 25      Missouri                    0.03                    0.04
# 44          Utah                    0.03                    0.04

# %%
# SAT top participation rates for 2018

final[['state', '2017_sat_participation', '2018_sat_participation']].sort_values(by='2018_sat_participation', ascending=False).head()
# Out:
#           state  2017_sat_participation  2018_sat_participation
# 5      Colorado                    0.11                     1.0
# 6   Connecticut                    1.00                     1.0
# 7      Delaware                    1.00                     1.0
# 22     Michigan                    1.00                     1.0
# 12        Idaho                    0.93                     1.0

# %%
# SAT lowest participation rates for 2018

final[['state', '2017_sat_participation', '2018_sat_participation']].sort_values(by='2018_sat_participation', ascending=True).head()
# Out:
#            state  2017_sat_participation  2018_sat_participation
# 34  North Dakota                    0.02                    0.02
# 50       Wyoming                    0.03                    0.03
# 41  South Dakota                    0.03                    0.03
# 27      Nebraska                    0.03                    0.03
# 49     Wisconsin                    0.03                    0.03

# %%
# ACT top participation rates for 2017

final[['state', '2017_act_participation', '2018_act_participation']].sort_values(by='2017_act_participation', ascending=False)
# Out:
#                    state  2017_act_participation  2018_act_participation
# 0                Alabama                    1.00                    1.00
# 17              Kentucky                    1.00                    1.00
# 49             Wisconsin                    1.00                    1.00
# 44                  Utah                    1.00                    1.00
# 42             Tennessee                    1.00                    1.00
# 40        South Carolina                    1.00                    1.00
# 36              Oklahoma                    1.00                    1.00
# 33        North Carolina                    1.00                    1.00
# 28                Nevada                    1.00                    1.00
# 26               Montana                    1.00                    1.00
# 24           Mississippi                    1.00                    1.00
# 23             Minnesota                    1.00                    0.99
# ...

# %%
# ACT lowest participation rates for 2017

final[['state', '2017_act_participation', '2018_act_participation']].sort_values(by='2017_act_participation', ascending=True).head()
# Out:
#             state  2017_act_participation  2018_act_participation
# 19          Maine                    0.08                    0.07
# 29  New Hampshire                    0.18                    0.16
# 7        Delaware                    0.18                    0.17
# 39   Rhode Island                    0.21                    0.15
# 38   Pennsylvania                    0.23                    0.20

# %%
# ACT top participation rates for 2018

final[['state', '2017_act_participation', '2018_act_participation']].sort_values(by='2018_act_participation', ascending=False)
# Out:
#                    state  2017_act_participation  2018_act_participation
# 0                Alabama                    1.00                    1.00
# 17              Kentucky                    1.00                    1.00
# 49             Wisconsin                    1.00                    1.00
# 44                  Utah                    1.00                    1.00
# 42             Tennessee                    1.00                    1.00
# 40        South Carolina                    1.00                    1.00
# 36              Oklahoma                    1.00                    1.00
# 35                  Ohio                    0.75                    1.00
# 33        North Carolina                    1.00                    1.00
# 28                Nevada                    1.00                    1.00
# 27              Nebraska                    0.84                    1.00
# 26               Montana                    1.00                    1.00
# ...

# %%
# ACT lowest participation rates for 2018

final[['state', '2017_act_participation', '2018_act_participation']].sort_values(by='2018_act_participation', ascending=True).head()
# Out:
#             state  2017_act_participation  2018_act_participation
# 19          Maine                    0.08                    0.07
# 39   Rhode Island                    0.21                    0.15
# 29  New Hampshire                    0.18                    0.16
# 7        Delaware                    0.18                    0.17
# 38   Pennsylvania                    0.23                    0.20

# %% [markdown]
# ### Participation Rate Summary:
#
# **SAT**
# 1. 2017 top states for participation rate: District of Columbia, Michigan, Connecticut and Delaware - 100% rate
# 2. 2017 lowest states for participation rate: North Dakota, Mississippi and Iowa - 2% rate
# 1. 2018 top states for participation rate: Colorado, Connecticut, Delaware, Michigan and Idaho - 100% rate
# 2. 2018 lowest states for participation rate: North Dakota - 2% rate
#
# **ACT**
# 1. 2017 top states for participation rate: Alabama, Kentucky, Wisconsin, Utah and Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado, Arkansas - 100% rate
# 2. 2017 lowest states for participation rate: Maine - 8% rate
# 1. 2018 top states for participation rate: Alabama, Kentucky, Wisconsin, Utah and Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Nevada, Nebraska, Montana, Mississippi, Louisiana, Missouri, Wyoming and Arkansas - 100% rate
# 2. 2018 lowest states for participation rate: Maine - 7% rate
#
# **Other observations:**
#
# - It is easier to get high ACT participation rates for the states but not SAT
# - SAT: District of Columbia fell in ranking while Michigan, Connecticut and Deleware maintained their top positions from 2017 to 2018
# - SAT: Colorado's participation rate grew very sharply from 2017 (11%) to 2018 (100%)

# %% [markdown]
# Which states have the highest and lowest mean total/composite scores for the 2017, 2018 SAT and ACT?

# %%
# SAT top scores for 2017

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2017_sat_total', ascending=False).head()
# Out:
#         state  2017_sat_total  2018_sat_total
# 23  Minnesota            1295            1298
# 49  Wisconsin            1291            1294
# 15       Iowa            1275            1265
# 25   Missouri            1271            1262
# 16     Kansas            1260            1265

# %%
# SAT top scores for 2018

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2018_sat_total', ascending=False).head()
# Out:
#            state  2017_sat_total  2018_sat_total
# 23     Minnesota            1295            1298
# 49     Wisconsin            1291            1294
# 34  North Dakota            1256            1283
# 15          Iowa            1275            1265
# 16        Kansas            1260            1265

# %%
# SAT lowest scores for 2017

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2017_sat_total', ascending=True).head()
# Out:
#                    state  2017_sat_total  2018_sat_total
# 8   District of Columbia             950             977
# 7               Delaware             996             998
# 12                 Idaho            1005            1001
# 22              Michigan            1005            1011
# 19                 Maine            1012            1013

# %%
# SAT lowest scores for 2018

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2018_sat_total', ascending=True).head()
# Out:
#                    state  2017_sat_total  2018_sat_total
# 8   District of Columbia             950             977
# 7               Delaware             996             998
# 48         West Virginia            1086             999
# 12                 Idaho            1005            1001
# 44                  Utah            1238            1010

# %%
# ACT top scores for 2017

final[['state', '2017_act_composite', '2018_act_composite']].sort_values(by='2017_act_composite', ascending=False).head()
# Out:
#                    state  2017_act_composite  2018_act_composite
# 29         New Hampshire                25.5                25.1
# 21         Massachusetts                25.4                25.5
# 6            Connecticut                25.2                25.6
# 19                 Maine                24.3                24.0
# 8   District of Columbia                24.2                23.6

# %%
# ACT top scores for 2018

final[['state', '2017_act_composite', '2018_act_composite']].sort_values(by='2018_act_composite', ascending=False).head()
# Out:
#             state  2017_act_composite  2018_act_composite
# 6     Connecticut                25.2                25.6
# 21  Massachusetts                25.4                25.5
# 29  New Hampshire                25.5                25.1
# 32       New York                24.2                24.5
# 22       Michigan                24.1                24.2

# %%
# ACT lowest scores for 2017

final[['state', '2017_act_composite', '2018_act_composite']].sort_values(by='2017_act_composite', ascending=True).head()
# Out:
#              state  2017_act_composite  2018_act_composite
# 28          Nevada                17.8                17.7
# 24     Mississippi                18.6                18.6
# 40  South Carolina                18.7                18.3
# 11          Hawaii                19.0                18.9
# 33  North Carolina                19.1                19.1

# %%
# ACT lowest scores for 2018

final[['state', '2017_act_composite', '2018_act_composite']].sort_values(by='2018_act_composite', ascending=True).head()
# Out:
#              state  2017_act_composite  2018_act_composite
# 28          Nevada                17.8                17.7
# 40  South Carolina                18.7                18.3
# 24     Mississippi                18.6                18.6
# 11          Hawaii                19.0                18.9
# 0          Alabama                19.2                19.1

# %% [markdown]
# ### Score Summary:
#
# **SAT**
# 1. 2017 top states: Minnesota - 1295
# 2. 2017 lowest states: District of Columbia - 950
# 1. 2018 top states: Minnesota - 1298
# 2. 2018 lowest states: District of Columbia - 977
#
# **ACT**
# 1. 2017 top states: New Hampshire - 25.5
# 2. 2017 lowest states: Nevada - 17.8
# 1. 2018 top states: Connecticut - 25.6
# 2. 2018 lowest states: Nevada - 17.7
#
# **Other Observations**
# 1. Minnesota retained its top ranking in 2018 SAT from 2017
# 2. District of Columbia remained last in ranking for both 2017 and 2018 SAT
# 3. Nevada remained last in ranking for both 2017 and 2018 ACT

# %% [markdown]
# ### Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
# We will look at states with 100% SAT participation rate
final[(final['2017_sat_participation'] == 1)][['state', '2017_sat_participation', '2018_sat_participation']]
# Out:
#                    state  2017_sat_participation  2018_sat_participation
# 6            Connecticut                     1.0                    1.00
# 7               Delaware                     1.0                    1.00
# 8   District of Columbia                     1.0                    0.92
# 22              Michigan                     1.0                    1.00

# %% [markdown]
# District of Columbia had 100% SAT participation for 2017 but fell to 92% in 2018

# %%
# We will look at states with 100% ACT participation rate
final[(final['2017_act_participation'] == 1)][['state', '2017_act_participation', '2018_act_participation']]
# Out:
#              state  2017_act_participation  2018_act_participation
# 0          Alabama                     1.0                    1.00
# 3         Arkansas                     1.0                    1.00
# 5         Colorado                     1.0                    0.30
# 17        Kentucky                     1.0                    1.00
# 18       Louisiana                     1.0                    1.00
# 23       Minnesota                     1.0                    0.99
# 24     Mississippi                     1.0                    1.00
# 25        Missouri                     1.0                    1.00
# 26         Montana                     1.0                    1.00
# 28          Nevada                     1.0                    1.00
# 33  North Carolina                     1.0                    1.00
# 36        Oklahoma                     1.0                    1.00
# 40  South Carolina                     1.0                    1.00
# ...

# %% [markdown]
# Colorado and Minnesota had decrease in ACT participation from 2017 to 2018. Particularly, Colorado fell significantly from 100% to 30%

# %% [markdown]
# ### Which states have the highest SAT and ACT scores?

# %% [markdown]
# ### Highest SAT Scores

# %%
# let us see the top states in terms of SAT scores for latest year 2017

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2017_sat_total', ascending=False).head()
# Out:
#         state  2017_sat_total  2018_sat_total
# 23  Minnesota            1295            1298
# 49  Wisconsin            1291            1294
# 15       Iowa            1275            1265
# 25   Missouri            1271            1262
# 16     Kansas            1260            1265

# %%
# let us see the top states in terms of SAT scores for latest year 2018

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2018_sat_total', ascending=False).head()
# Out:
#            state  2017_sat_total  2018_sat_total
# 23     Minnesota            1295            1298
# 49     Wisconsin            1291            1294
# 34  North Dakota            1256            1283
# 15          Iowa            1275            1265
# 16        Kansas            1260            1265

# %% [markdown]
# Minnesota had the highest mean SAT score for 2018 - 1298.

# %%
# let us create a new coloumn for the % difference of 2017 and 2018 SAT scores
final['sat_score_percent_diff_2017-18'] = round((final['2018_sat_total'] - final['2017_sat_total']) / final['2017_sat_total'] * 100, 1)

# %%
highest_sat_scores_2018 = final[['state', '2017_sat_total', '2018_sat_total', 'sat_score_percent_diff_2017-18']].sort_values(by='2018_sat_total', ascending=False)[:5]
highest_sat_scores_2018
# Out:
#            state  2017_sat_total  2018_sat_total  \
# 23     Minnesota            1295            1298
# 49     Wisconsin            1291            1294
# 34  North Dakota            1256            1283
# 15          Iowa            1275            1265
# 16        Kansas            1260            1265
#
#     sat_score_percent_diff_2017-18
# 23                             0.2
# 49                             0.2
# 34                             2.1
# 15                            -0.8
# 16                             0.4

# %% [markdown]
# We also note that there has not been much impact to the scores with the exception of Iowa. North Dakota, on the other hand, had an healthy increase in score (2.1%)

# %% [markdown]
# ### Highest ACT Scores

# %%
# let us see the top states in terms of ACT scores for latest year 2018

final[['state', '2017_act_composite', '2018_act_composite']].sort_values(by='2018_act_composite', ascending=False).head()
# Out:
#             state  2017_act_composite  2018_act_composite
# 6     Connecticut                25.2                25.6
# 21  Massachusetts                25.4                25.5
# 29  New Hampshire                25.5                25.1
# 32       New York                24.2                24.5
# 22       Michigan                24.1                24.2

# %% [markdown]
# Connecticut had the highest mean ACT score for 2018 - 25.6

# %%
# let us create a new coloumn for the % difference of 2017 and 2018 ACT scores
final['act_score_percent_diff_2017-18'] = round((final['2018_act_composite'] - final['2017_act_composite']) / final['2017_act_composite'] * 100, 1)

# %%
highest_act_scores_2018 = final[['state', '2017_act_composite', '2018_act_composite', 'act_score_percent_diff_2017-18']].sort_values(by='2018_act_composite', ascending=False)[:5]
highest_act_scores_2018
# Out:
#             state  2017_act_composite  2018_act_composite  \
# 6     Connecticut                25.2                25.6
# 21  Massachusetts                25.4                25.5
# 29  New Hampshire                25.5                25.1
# 32       New York                24.2                24.5
# 22       Michigan                24.1                24.2
#
#     act_score_percent_diff_2017-18
# 6                              1.6
# 21                             0.4
# 29                            -1.6
# 32                             1.2
# 22                             0.4

# %% [markdown]
# We also note that there has not been much impact to the scores with the exception of New Hampshire (-1.6%). Connecticut, on the other hand, had an healthy increase in score (1.6%)

# %% [markdown]
# ### Which states have the lowest SAT and ACT scores?

# %% [markdown]
# ### Lowest SAT Scores

# %%
# let us see the top states in terms of SAT scores for latest year 2017

final[['state', '2017_sat_total', '2018_sat_total']].sort_values(by='2017_sat_total', ascending=True).head()
# Out:
#                    state  2017_sat_total  2018_sat_total
# 8   District of Columbia             950             977
# 7               Delaware             996             998
# 12                 Idaho            1005            1001
# 22              Michigan            1005            1011
# 19                 Maine            1012            1013

# %%
# let us see the lowest states in terms of SAT scores for year 2018
lowest_sat_scores_2018 = final[['state', '2017_sat_total', '2018_sat_total', 'sat_score_percent_diff_2017-18']].sort_values(by='2018_sat_total', ascending=True)[:5]
lowest_sat_scores_2018
# Out:
#                    state  2017_sat_total  2018_sat_total  \
# 8   District of Columbia             950             977
# 7               Delaware             996             998
# 48         West Virginia            1086             999
# 12                 Idaho            1005            1001
# 44                  Utah            1238            1010
#
#     sat_score_percent_diff_2017-18
# 8                              2.8
# 7                              0.2
# 48                            -8.0
# 12                            -0.4
# 44                           -18.4

# %% [markdown]
# West Virginia and Utah had drops in SAT scores. Utah in particular fell significantly (-18.4%), although the District of Columbia remains the weakest performing state for SAT 2018

# %% [markdown]
# ### Lowest ACT Scores

# %%
# let us see the lowest states in terms of ACT scores for year 2018
lowest_act_scores_2018 = final[['state', '2017_act_composite', '2018_act_composite', 'act_score_percent_diff_2017-18']].sort_values(by='2018_act_composite', ascending=True)[:5]
lowest_act_scores_2018
# Out:
#              state  2017_act_composite  2018_act_composite  \
# 28          Nevada                17.8                17.7
# 40  South Carolina                18.7                18.3
# 24     Mississippi                18.6                18.6
# 11          Hawaii                19.0                18.9
# 0          Alabama                19.2                19.1
#
#     act_score_percent_diff_2017-18
# 28                            -0.6
# 40                            -2.1
# 24                             0.0
# 11                            -0.5
# 0                             -0.5

# %% [markdown]
# With the exception of South Carolina (score fell by 2.1%), there was minimal changes to the ACT scores of the lowest performing states in 2018

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Heatmap

# %%
# Heatmap

plt.figure(figsize=(15, 12))
matrix = np.triu(final.corr())

sns.heatmap(final.corr(), cmap = 'coolwarm', mask=matrix, annot=True)

plt.title('Correlation Matrix \n2017 and 2018 Participation Rate and SAT & ACT Scores', size = 15);

# %% [markdown]
# **Observations:**
# - We see strong correlation between the 2017 ACT score and its respective sections of the test.
# - This meant that if students did well in the English section, they were likely to do well in the Math section, similar to Science and English, and Science and Math
# - Strong correlation is also observed between 2017 SAT score and its respective sections, likewise for 2018 SAT
# - There is strong negative correlation between SAT scores and SAT participation rates for 2017 (-0.87)
# - There is strong negative correlation between SAT scores and SAT participation rates for 2018 (-0.79)
# - We were unable to identify correlation for 2018's ACT test sections as the data was not provided.

# %% [markdown]
# ### Histogram for all variables

# %%
# histograms for all variables
final.hist(figsize=(12, 12), bins=30);
plt.tight_layout();

# %% [markdown]
# ### SAT

# %% [markdown]
# Analysis on Scores:
# 1. 2017 & 2018: we note that SAT total scores generally vary across the scoring range
#
# Analysis on participation rates:
# 1. 2017: we note that majority of the states had low SAT participation rates
# 2. 2018: we still saw many states with low rates but there was an increase in states which had close to full participation

# %% [markdown]
# ### ACT

# %% [markdown]
# Analysis on Scores:
# 1. 2017 & 2018: ACT composite scores generally vary across the scoring range
#
# Analysis on participation rates:
# 1. Both 2017 and 2018 saw majority of the states with close to 100% participation

# %% [markdown]
# ### Pairplots for participation rates and scores (SAT)

# %%
# finding any correlation between SAT scores and SAT participation rates
sns.pairplot(final[['2017_sat_participation', '2017_sat_total', '2018_sat_participation', '2018_sat_total', ]])

# %% [markdown]
# **Observation**
# - For SAT, we are looking for any correlation between participation rates and scores
# - We can see that there is some negative correlation to the SAT scores and SAT participation, it seems like the lower the participation rate, the higher the SAT scores

# %% [markdown]
# ### Pairplots for participation rates and scores (ACT)

# %%
sns.pairplot(final[['2017_act_participation', '2017_act_composite', '2018_act_participation', '2018_act_composite']])

# %% [markdown]
# **Observation**
# - There is some negative correlation to the ACT scores and ACT participation for 2017 and 2018

# %% [markdown]
# ### Scatter Plots

# %%
# let us take a closer look at plots for SAT score and participation rates for both 2017 and 2018

# %%
# plot for SAT score and participation rates for 2018

x = final['2018_sat_total']
y = final['2018_sat_participation']

plt.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x + b)

plt.title('Relationship of SAT Scores & Participation Rates for 2018', fontsize=15)
plt.xlabel('2018 SAT Scores')
plt.ylabel('SAT Participation Rates');

# %% [markdown]
# Interestingly, in 2018: states that score the highest had one of the lowest participation rates

# %%
# plot for SAT score and participation rates for 2017

x = final['2017_sat_total']
y = final['2017_sat_participation']

plt.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x + b)

plt.title('Relationship of SAT Scores & Participation Rates for 2017', fontsize=15)
plt.xlabel('SAT Scores')
plt.ylabel('SAT Participation Rates');

# %% [markdown]
# The scores and participation rates had a similar relationship in for 2017 SAT as well i.e. top performing states had low participation rates

# %% [markdown]
# ### Box Plots

# %%
sns.boxplot(data=final[['2018_sat_total', '2017_sat_total']], orient='h');

# %% [markdown]
# When comparing both SAT scores for 2017 and 2018, we do see a slight improvement in the median score.
#
# The interquartile range for 2018 scores is more concentrated than 2017 scores
#
# For both box plots, there are no outliers observed.

# %% [markdown]
# ## Some bar charts to show the score variance of highest/lowest performing states of 2018

# %%
# let us plot the SAT score variance for highest performing states in 2018
# we will adjust yticks for better comparison with other charts

plt.figure(figsize=(12, 5))

plt.bar(x = highest_sat_scores_2018['state'],
       height = highest_sat_scores_2018['sat_score_percent_diff_2017-18'], 
       color=['grey', 'grey', 'grey', 'red', 'grey'])

plt.title('SAT Average Score for Top 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-20, 5, 2));

# %%
# let us plot the ACT score variance for highest performing states in 2018
# we will adjust yticks for better comparison with other charts
plt.figure(figsize=(12, 5))

plt.bar(x = highest_act_scores_2018['state'],
       height = highest_act_scores_2018['act_score_percent_diff_2017-18'], 
       color=['grey', 'grey', 'red', 'grey', 'grey'])

plt.title('ACT Average Score for Top 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-2, 2, 0.5));

# %%
# adjusted yticks to compare with SAT charts

plt.figure(figsize=(12, 5))

plt.bar(x = highest_act_scores_2018['state'],
       height = highest_act_scores_2018['act_score_percent_diff_2017-18'], 
       color=['grey', 'grey', 'red', 'grey', 'grey'])

plt.title('ACT Average Score for Top 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-20, 5, 2));

# %%
# let us plot the SAT score variance for lowest performing states in 2018
# we will adjust yticks for better comparison with other charts

plt.figure(figsize=(12, 5))

plt.bar(lowest_sat_scores_2018['state'],
       lowest_sat_scores_2018['sat_score_percent_diff_2017-18'],
        color=['grey', 'grey', 'red', 'red', 'red'])

plt.title('SAT Average Score for Bottom 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-20, 5, 2));

# %% [markdown]
# ### Zooming to see more details on Utah's Score

# %%
final.loc[final['state'] == 'Utah', ['state', '2017_sat_read_write', '2018_sat_read_write', '2017_sat_math', '2018_sat_math']]
# Out:
#    state  2017_sat_read_write  2018_sat_read_write  2017_sat_math  \
# 44  Utah                  624                  480            614
#
#     2018_sat_math
# 44            530

# %%
480-624
# Out:
# -144

# %%
530-480
# Out:
# 50

# %% [markdown]
# With further analysis on Utah's score, we observed that the large drop in SAT score was primarily influenced by the Evidence-Based Reading and Writing Section

# %% [markdown]
# ### Zooming to see more details on West Virginia's Score

# %%
final.loc[final['state'] == 'West Virginia', ['state', '2017_sat_read_write', '2018_sat_read_write', '2017_sat_math', '2018_sat_math']]
# Out:
#             state  2017_sat_read_write  2018_sat_read_write  2017_sat_math  \
# 48  West Virginia                  558                  513            528
#
#     2018_sat_math
# 48            486

# %%
513-558
# Out:
# -45

# %%
486-528
# Out:
# -42

# %% [markdown]
# With further analysis on West Virginia's score, we observed that the drop in SAT score was equally influenced by both the Evidence-Based Reading and Writing Section and Math Section

# %%
# let us plot the ACT score variance for lowest performing states in 2018
# we will adjust yticks for better comparison with other charts

plt.figure(figsize=(12, 5))

plt.bar(lowest_act_scores_2018['state'],
        lowest_act_scores_2018['act_score_percent_diff_2017-18'],
        color=['red', 'red', 'grey', 'red', 'red'])

plt.title('ACT Average Score for Bottom 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-2, 1.5, 0.5));

# %%
# adjusted for yticks to compare with SAT charts

plt.figure(figsize=(12, 5))

plt.bar(lowest_act_scores_2018['state'],
        lowest_act_scores_2018['act_score_percent_diff_2017-18'],
        color=['red', 'red', 'grey', 'red', 'red'])

plt.title('ACT Average Score for Bottom 5 Performing States in 2018\n (2018 Score over 2017 Score Difference in %)', fontsize=20);
plt.ylabel('% Change');
plt.yticks(np.arange(-20, 5, 2));

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Key Takeaways:**
# 1. The new SAT format impacted the scores of bottom 5 performing states
# 2. Top performing states adapted well to the new SAT format
# 3. Bottom 5 states saw drops in scores after the new format was implemented
#
#
# **Recommendations:**
# 1. Allocate resources to lowest performing states for SAT scores to help support those students and bridge the scoring gap nationally.
# - Specifically for Utah, the section which students were performing poorly was the Evidence-Based Reading and Writing Section. This led to the large drop for its SAT score in 2018
#
# 2. Improve the exam format based on continuous feedback after encouraging more participation across the states
#
# **Limitations:**
# 1. Our data on SAT scores may not be an accurate measurement of students’ ability in a particular state if participation rates vary widely

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
