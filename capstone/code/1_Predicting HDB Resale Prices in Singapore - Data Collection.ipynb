# %% [markdown]
# # 1. Data Collection

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Due to covid and the presence of lockdowns which has affected public housing project delays in Singapore, HDB resale prices has been steadily increasing and has become a common discussion topics especially amongst first time young buyers.
#
# I am curious to find out what features influence HDB resale prices and help potential buyers find out if the current asking prices of HDBs are reasonable by using regression models to predict HDB prices.
#
# The increasing cost of living comes to mind for young Singaporeans looking to purchase a home and start a family. This model would serve a guide for them as part of their home purchase decision making process.
#
# Regression models for consideration: Linear, Lasso, Ridge, Random Forest, XGBoost, Neural Networks
#
# Success Metrics: Model performance will be guided by RMSE. We will seek to find the best performing model based on the lowest RMSE score.

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import requests

# %% [markdown]
# # Reading in HDB Data Sources

# %% [markdown]
# Data received from https://data.gov.sg/dataset/resale-flat-prices with HDB resale transactions dating back to 1990. Most recent data is Oct 2021.

# %%
pd.set_option('display.max_rows', 1000)

# %%
hdb_2000_2012feb = pd.read_csv('../datasets/original-hdb-data/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv')
hdb_2012mar_2014dec = pd.read_csv('../datasets/original-hdb-data/resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv')
hdb_2015_2016 = pd.read_csv('../datasets/original-hdb-data/resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv')
hdb_2017_to_recent = pd.read_csv('../datasets/original-hdb-data/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv')

# %%
# briefly examine df
hdb_2017_to_recent.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
# checking data types
hdb_2017_to_recent.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %%
hdb_2017_to_recent['flat_model'].unique()
# Out:
# array(['Improved', 'New Generation', 'DBSS', 'Standard', 'Apartment',
#        'Simplified', 'Model A', 'Premium Apartment', 'Adjoined flat',
#        'Model A-Maisonette', 'Maisonette', 'Type S1', 'Type S2',
#        'Model A2', 'Terrace', 'Improved-Maisonette', 'Premium Maisonette',
#        'Multi Generation', 'Premium Apartment Loft', '2-room'],
#       dtype=object)

# %%
hdb_2017_to_recent['flat_type'].unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %% [markdown]
# # Collecting Longitudes and Latitudes of HDB transactions

# %% [markdown]
# - Create longitude and latitude columns
#
# Real estate prices are closely driven by location. We will create longitude and latitude data from the block and street_name columns to get their exact locations by calling the government's OneMap API.

# %%
# create function to add in new columns to df
def add_long_lat(df):
    
    '''add longitude and latitude columns to the df'''
    
    df['longitude'] = ''
    df['latitude'] = ''
    return df

# %%
# function to get lat and long of the hdb using OneMap API
def get_coordinate(df, df_name):
    
    '''get HDB coordinate by calling the OneMap API through searching with block and street name data'''
    
    row = 0        

    for block, street in zip(df['block'], df['street_name']):  

        if df['longitude'][row] != '':               # skip row if coordinates already filled
            print(f'Row {row} already filled')       
            row += 1                                 # shift to check next row 

        else:

            url = f'https://developers.onemap.sg/commonapi/search?searchVal={block} {street}&returnGeom=Y&getAddrDetails=Y'
            res = requests.get(url)

            # Check Status Code
            if res.status_code != 200:
                print("Error",res.status_code)
                break

            else:

                print(f'{row} Retrieved coordinates from {url}')
                data = res.json()

                try:
                    longitude = data['results'][0]['LONGITUDE']
                    latitude = data['results'][0]['LATITUDE']

                # if no data, we will return empty strings
                except:
                    longitude = ''
                    latitude = ''

                df['longitude'][row] = longitude
                df['latitude'][row] = latitude

                row += 1
                df.to_csv(f'{df_name}.csv', index=False)


    return df

# %%
# add_long_lat(hdb_2017_to_recent)

# %%
#get_coordinate(hdb_2017_to_recent, 'hdb_2017_recent_long_lat')

# %%
#add_long_lat(hdb_2015_2016)

# %%
#get_coordinate(hdb_2015_2016, 'hdb_2015_2016_long_lat')

# %%
#add_long_lat(hdb_2012mar_2014dec)

# %%
#get_coordinate(hdb_2012mar_2014dec, 'hdb_2012mar_2014dec_long_lat')

# %%
# extracting data from oct 2011 to 2012 feb
# this will complete the entire data collection of 10 years worth of HDB transaction

hdb_2011_oct = hdb_2000_2012feb[hdb_2000_2012feb['month'].str.contains('2011-10')]
hdb_2011_nov = hdb_2000_2012feb[hdb_2000_2012feb['month'].str.contains('2011-11')]
hdb_2011_dec = hdb_2000_2012feb[hdb_2000_2012feb['month'].str.contains('2011-12')]
hdb_2012_to_feb = hdb_2000_2012feb[hdb_2000_2012feb['month'].str.contains('2012')]

# %%
hdb_2011_oct_to_2012_feb = pd.concat([hdb_2011_oct, hdb_2011_nov, hdb_2011_dec, hdb_2012_to_feb])
hdb_2011_oct_to_2012_feb.shape
# Out:
# (8120, 12)

# %%
#add_long_lat(hdb_2011_oct_to_2012_feb)

# %%
#hdb_2011_oct_to_2012_feb.index = np.arange(len(hdb_2011_oct_to_2012_feb))

# %%
#get_coordinate(hdb_2011_oct_to_2012_feb, 'hdb_2011_oct_to_2012_feb_long_lat')

# %% [markdown]
# # Collecting Longitudes and latitudes of Amenities

# %%
# create function to pull long, lat of amenities
def get_amenities(amenity_search, num_page, amenity_df, amenity_col_name):
    ls = []

    for page in range(1,num_page+1):

        try:

            url = f'https://developers.onemap.sg/commonapi/search?searchVal={amenity_search}&returnGeom=Y&getAddrDetails=Y&pageNum={page}'
            res = requests.get(url)

            # Check Status Code
            if res.status_code != 200:
                print("Error",res.status_code)

            else:
                print(f'Retrieved page {page} for {amenity_search} geo coordinates')
                data = res.json()
                for i in range(10):
                    results = {amenity_col_name: data['results'][i]['BUILDING'],
                           'longitude': data['results'][i]['LONGITUDE'],
                           'latitude': data['results'][i]['LATITUDE']}
                    ls.append(results)

                page += 1
                
                

        except:
            pass
    
    amenity_df = pd.DataFrame(ls)
    amenity_df.to_csv(f'../datasets/amenities/{amenity_col_name}.csv', index=False)
    
    return amenity_df

# %% [markdown]
# ## Scraping MRT station coordinates

# %%
mrt = get_amenities('mrt station', 100, 'mrt_stn', 'mrt_station')
mrt
# Out:
# Retrieved Page1 for mrt station Coordinates
# Retrieved Page2 for mrt station Coordinates
# Retrieved Page3 for mrt station Coordinates
# Retrieved Page4 for mrt station Coordinates
# Retrieved Page5 for mrt station Coordinates
# Retrieved Page6 for mrt station Coordinates
# Retrieved Page7 for mrt station Coordinates
# Retrieved Page8 for mrt station Coordinates
# Retrieved Page9 for mrt station Coordinates
# Retrieved Page10 for mrt station Coordinates
# Retrieved Page11 for mrt station Coordinates
# Retrieved Page12 for mrt station Coordinates
# Retrieved Page13 for mrt station Coordinates
# Retrieved Page14 for mrt station Coordinates
# Retrieved Page15 for mrt station Coordinates
# Retrieved Page16 for mrt station Coordinates
# Retrieved Page17 for mrt station Coordinates
# Retrieved Page18 for mrt station Coordinates
# Retrieved Page19 for mrt station Coordinates
# Retrieved Page20 for mrt station Coordinates
# Retrieved Page21 for mrt station Coordinates
# Retrieved Page22 for mrt station Coordinates
# Retrieved Page23 for mrt station Coordinates
# Retrieved Page24 for mrt station Coordinates
# Retrieved Page25 for mrt station Coordinates
# Retrieved Page26 for mrt station Coordinates
# Retrieved Page27 for mrt station Coordinates
# Retrieved Page28 for mrt station Coordinates
# Retrieved Page29 for mrt station Coordinates
# Retrieved Page30 for mrt station Coordinates
# Retrieved Page31 for mrt station Coordinates
# Retrieved Page32 for mrt station Coordinates
# Retrieved Page33 for mrt station Coordinates
# Retrieved Page34 for mrt station Coordinates
# Retrieved Page35 for mrt station Coordinates
# Retrieved Page36 for mrt station Coordinates
# Retrieved Page37 for mrt station Coordinates
# Retrieved Page38 for mrt station Coordinates
# Retrieved Page39 for mrt station Coordinates
# Retrieved Page40 for mrt station Coordinates
# Retrieved Page41 for mrt station Coordinates
# Retrieved Page42 for mrt station Coordinates
# Retrieved Page43 for mrt station Coordinates
# Retrieved Page44 for mrt station Coordinates
# Retrieved Page45 for mrt station Coordinates
# Retrieved Page46 for mrt station Coordinates
# Retrieved Page47 for mrt station Coordinates
# Retrieved Page48 for mrt station Coordinates
# Retrieved Page49 for mrt station Coordinates
# Retrieved Page50 for mrt station Coordinates
# Retrieved Page51 for mrt station Coordinates
# Retrieved Page52 for mrt station Coordinates
# Retrieved Page53 for mrt station Coordinates
# Retrieved Page54 for mrt station Coordinates
# Retrieved Page55 for mrt station Coordinates
# Retrieved Page56 for mrt station Coordinates
# Retrieved Page57 for mrt station Coordinates
# Retrieved Page58 for mrt station Coordinates
# Retrieved Page59 for mrt station Coordinates
# Retrieved Page60 for mrt station Coordinates
# Retrieved Page61 for mrt station Coordinates
# Retrieved Page62 for mrt station Coordinates
# Retrieved Page63 for mrt station Coordinates
# Retrieved Page64 for mrt station Coordinates
# Retrieved Page65 for mrt station Coordinates
# Retrieved Page66 for mrt station Coordinates
# Retrieved Page67 for mrt station Coordinates
# Retrieved Page68 for mrt station Coordinates
# Retrieved Page69 for mrt station Coordinates
# Retrieved Page70 for mrt station Coordinates
# Retrieved Page71 for mrt station Coordinates
# Retrieved Page72 for mrt station Coordinates
# Retrieved Page73 for mrt station Coordinates
# Retrieved Page74 for mrt station Coordinates
# Retrieved Page75 for mrt station Coordinates
# Retrieved Page76 for mrt station Coordinates
# Retrieved Page77 for mrt station Coordinates
# Retrieved Page78 for mrt station Coordinates
# Retrieved Page79 for mrt station Coordinates
# Retrieved Page80 for mrt station Coordinates
# Retrieved Page81 for mrt station Coordinates
# Retrieved Page82 for mrt station Coordinates
# Retrieved Page83 for mrt station Coordinates
# Retrieved Page84 for mrt station Coordinates
# Retrieved Page85 for mrt station Coordinates
# Retrieved Page86 for mrt station Coordinates
# Retrieved Page87 for mrt station Coordinates
# Retrieved Page88 for mrt station Coordinates
# Retrieved Page89 for mrt station Coordinates
# Retrieved Page90 for mrt station Coordinates
# Retrieved Page91 for mrt station Coordinates
# Retrieved Page92 for mrt station Coordinates
# Retrieved Page93 for mrt station Coordinates
# Retrieved Page94 for mrt station Coordinates
# Retrieved Page95 for mrt station Coordinates
# Retrieved Page96 for mrt station Coordinates
# Retrieved Page97 for mrt station Coordinates
# Retrieved Page98 for mrt station Coordinates
# Retrieved Page99 for mrt station Coordinates
# Retrieved Page100 for mrt station Coordinates
#                                            mrt station         longitude  \
# 0                  CITY HALL MRT STATION (EW13 / NS25)  103.852585580366
# 1                    BAYFRONT MRT STATION (DT16 / CE1)  103.859079764874
# 2               SUNGEI BEDOK MRT STATION (TE31 / DT37)  103.957183823478
# 3                HARBOURFRONT MRT STATION (NE1 / CC29)  103.821530157095
# 4                 JURONG EAST MRT STATION (EW24 / NS1)  103.742286332403
# 5              RAFFLES PLACE MRT STATION (EW14 / NS26)  103.851461712342
# 6                          CALDECOTT MRT STATION (TE9)  103.840161782075
# 7                             CASHEW MRT STATION (DT2)   103.76443921414
# 8                             LENTOR MRT STATION (TE5)  103.835743809669
# 9                          SOMERSET MRT STATION (NS23)  103.839085753124
# 10                     UPPER THOMSON MRT STATION (TE8)  103.832898468504
# 11                       MARINA BAY MRT STATION (NS27)  103.854595522263
# 12                        MARINA BAY MRT STATION (CE2)  103.855447156279
# 13                      SHENTON WAY MRT STATION (TE19)  103.850367596067
# 14                       MARINA BAY MRT STATION (TE20)  103.855309167928
# 15                MARINA SOUTH PIER MRT STATION (NS28)  103.862447515736
# 16                         DOWNTOWN MRT STATION (DT17)  103.852840829581
# 17               GARDENS BY THE BAY MRT STATION (TE22)  103.867454664421
# 18                     MARINA SOUTH MRT STATION (TE21)  103.863574321728
# 19                             EXPO MRT STATION (DT35)  103.962374747451
# 20                           NAPIER MRT STATION (TE12)  103.818967003926
# 21                    TAMPINES WEST MRT STATION (DT31)  103.938436971222
# 22                   TANJONG KATONG MRT STATION (TE25)  103.897368742078
# 23                      TANJONG RHU MRT STATION (TE23)  103.873453254621
# 24                  KING ALBERT PARK MRT STATION (DT6)  103.783399113441
# 25                         PROMENADE MRT STATION (CC4)  103.860350000188
# 26                           STADIUM MRT STATION (CC6)  103.875337711089
# 27                    NICOLL HIGHWAY MRT STATION (CC5)   103.86363696572
# 28                        PROMENADE MRT STATION (DT15)  103.860891800025
# 29                       TELOK AYER MRT STATION (DT18)  103.848648781083
# 30                         SENGKANG MRT STATION (NE16)  103.895484694279
# 31                          KALLANG MRT STATION (EW10)  103.871386541754
# 32                        CHINATOWN MRT STATION (DT19)  103.845143798953
# 33                          MAXWELL MRT STATION (TE18)  103.843883670633
# 34                         CHINATOWN MRT STATION (NE4)  103.843426681863
# 35                       CLARKE QUAY MRT STATION (NE5)  103.846555209694
# 36                       OUTRAM PARK MRT STATION (NE3)  103.839439862425
# 37                    TANJONG PAGAR MRT STATION (EW15)  103.845725186759
# 38               PRINCE EDWARD ROAD MRT STATION (CC32)  103.847097123745
# 39                       CANTONMENT MRT STATION (CC31)  103.837062313764
# 40                        ONE-NORTH MRT STATION (CC23)   103.78745750525
# 41         OCBC HARBOURFRONT MRT STATION (CIRCLE LINE)  103.821667373619
# 42                           KEPPEL MRT STATION (CC30)  103.830031459524
# 43                              EXPO MRT STATION (CG1)  103.961548211018
# 44                         BRADDELL MRT STATION (NS18)  103.846799083148
# 45                         TAMPINES MRT STATION (DT32)  103.943009883131
# 46                          TAMPINES MRT STATION (EW2)  103.945144586749
# 47                       KAKI BUKIT MRT STATION (DT28)  103.908459338046
# 48                     CHOA CHU KANG MRT STATION (NS4)  103.744370779756
# 49                         BUANGKOK MRT STATION (NE15)  103.893122569706
# 50                       BUKIT BATOK MRT STATION (NS2)  103.749566478309
# 51                       MACPHERSON MRT STATION (DT26)  103.889298600376
# 52                      OUTRAM PARK MRT STATION (EW16)  103.839130979249
# 53                         PASIR RIS MRT STATION (EW1)  103.949284527763
# 54                  BOTANIC GARDENS MRT STATION (CC19)  103.814984510627
# 55                       BRIGHT HILL MRT STATION (TE7)  103.832893619992
# 56                      BUONA VISTA MRT STATION (EW21)  103.790253514502
# 57                           SIGLAP MRT STATION (TE28)  103.930025826702
# 58                      BEAUTY WORLD MRT STATION (DT5)  103.775794285083
# 59                    MARINE PARADE MRT STATION (TE26)  103.904983086812
# 60                    PUNGGOL COAST MRT STATION (NE18)  103.910166388177
# 61                    TELOK BLANGAH MRT STATION (CC28)  103.809761611219
# 62                    LABRADOR PARK MRT STATION (CC27)  103.802631578766
# 63                      DHOBY GHAUT MRT STATION (NS24)  103.846113677951
# 64                        BENDEMEER MRT STATION (DT23)  103.862977620945
# 65                         CANBERRA MRT STATION (NS12)  103.829702590959
# 66                        SEMBAWANG MRT STATION (NS11)  103.820046140211
# 67                           ROCHOR MRT STATION (DT13)  103.852769428884
# 68                         WOODLANDS MRT STATION (TE2)  103.787938777173
# 69                         HAVELOCK MRT STATION (TE16)  103.833585838226
# 70                    HAW PAR VILLA MRT STATION (CC25)  103.781752725064
# 71                    PASIR PANJANG MRT STATION (CC26)  103.791350313288
# 72                       KENT RIDGE MRT STATION (CC24)  103.784572738173
# 73                         CLEMENTI MRT STATION (EW23)  103.765191452888
# 74                       DHOBY GHAUT MRT STATION (CC1)   103.84629250696
# 75                      OUTRAM PARK MRT STATION (TE17)  103.839137557749
# 76                   TUAS WEST ROAD MRT STATION (EW32)  103.639616648771
# 77                            DOVER MRT STATION (EW22)  103.778637841909
# 78                      BUONA VISTA MRT STATION (CC22)  103.790709404436
# 79          OCBC BUONA VISTA MRT STATION (CIRCLE LINE)   103.79070940498
# 80                   MOUNT PLEASANT MRT STATION (TE10)  103.834688253778
# 81                       QUEENSTOWN MRT STATION (EW19)  103.806077155982
# 82                     COMMONWEALTH MRT STATION (EW20)  103.798228523336
# 83                        PAYA LEBAR MRT STATION (CC9)  103.892260753884
# 84                     LORONG CHUAN MRT STATION (CC14)  103.864151938651
# 85                   CHINESE GARDEN MRT STATION (EW25)  103.732596738363
# 86                          REDHILL MRT STATION (EW18)   103.81674097205
# 87                      TIONG BAHRU MRT STATION (EW17)  103.827445112419
# 88                           BISHAN MRT STATION (CC15)   103.84914026532
# 89                   WOODLANDS SOUTH MRT STATION (TE3)   103.79326432221
# 90                     FORT CANNING MRT STATION (DT20)  103.844331362465
# 91                       MACPHERSON MRT STATION (CC10)  103.890391305725
# 92                            BUGIS MRT STATION (EW12)  103.855706730933
# 93                            BUGIS MRT STATION (DT14)  103.857125958751
# 94                        BRAS BASAH MRT STATION (CC2)  103.850667371637
# 95                         ESPLANADE MRT STATION (CC3)  103.855081226245
# 96                        BENCOOLEN MRT STATION (DT21)  103.850353762717
# 97                           KHATIB MRT STATION (NS14)  103.832979908243
# 98                              UBI MRT STATION (DT27)  103.899226655439
# 99                         WOODLANDS MRT STATION (NS9)  103.786066799253
# 100                          YISHUN MRT STATION (NS13)  103.835005047246
# 101                   TAMPINES EAST MRT STATION (DT33)    103.9546344625
# 102               ORCHARD BOULEVARD MRT STATION (TE13)  103.823868523249
# 103                       TUAS LINK MRT STATION (EW33)  103.636991425128
# 104                  WOODLANDS NORTH MRT STATION (TE1)  103.785692682441
# 105                          BISHAN MRT STATION (NS17)  103.848143964542
# 106                 HOLLAND VILLAGE MRT STATION (CC21)  103.796399122407
# 107                           DAKOTA MRT STATION (CC8)  103.889064718377
# 108                        LAKESIDE MRT STATION (EW26)  103.720949087456
# 109                        LAVENDER MRT STATION (EW11)  103.862767633888
# 110                     JALAN BESAR MRT STATION (DT22)  103.855295713435
# 111                       SERANGOON MRT STATION (CC13)  103.872771660431
# 112                      FARRER PARK MRT STATION (NE8)  103.853477716509
# 113                          NEWTON MRT STATION (NS21)  103.837984594021
# 114                     LITTLE INDIA MRT STATION (NE7)  103.849647059738
# 115                          NEWTON MRT STATION (DT11)  103.837714613091
# 116                    LITTLE INDIA MRT STATION (DT12)  103.848660935092
# 117                         ORCHARD MRT STATION (TE14)  103.831375000068
# 118                     GREAT WORLD MRT STATION (TE15)  103.833720837731
# 119                         ORCHARD MRT STATION (NS22)  103.832245244375
# 120                      DHOBY GHAUT MRT STATION (NE6)  103.845488542541
# 121                         ALJUNIED MRT STATION (EW9)  103.882906044385
# 122                          NOVENA MRT STATION (NS20)  103.843825618748
# 123                         STEVENS MRT STATION (DT10)  103.826024401924
# 124                         STEVENS MRT STATION (TE11)  103.825566965234
# 125                  BOTANIC GARDENS MRT STATION (DT9)  103.816013994259
# 126                      TAN KAH KEE MRT STATION (DT8)  103.807760304729
# 127                     FARRER ROAD MRT STATION (CC20)  103.807379214161
# 128                     SIXTH AVENUE MRT STATION (DT7)  103.796906838288
# 129                      ANG MO KIO MRT STATION (NS16)   103.84955809232
# 130                       CALDECOTT MRT STATION (CC17)  103.839529820338
# 131                     BUKIT BROWN MRT STATION (CC18)  103.830689549849
# 132                 BEDOK RESERVOIR MRT STATION (DT30)  103.932234623286
# 133                        MARSILING MRT STATION (NS8)  103.774074641403
# 134                            SIMEI MRT STATION (EW3)  103.953377214378
# 135                            EUNOS MRT STATION (EW7)  103.903225807255
# 136                       PAYA LEBAR MRT STATION (EW8)  103.893060771576
# 137                    YIO CHU KANG MRT STATION (NS15)   103.84494727118
# 138                        BOON LAY MRT STATION (EW27)  103.706064622772
# 139                      MOUNTBATTEN MRT STATION (CC7)  103.882528081052
# 140                           XILIN MRT STATION (DT36)  103.964902569595
# 141                  MARINE TERRACE MRT STATION (TE27)    103.9151067005
# 142                        BAYSHORE MRT STATION (TE29)  103.942307986645
# 143                         PIONEER MRT STATION (EW28)  103.697321608474
# 144                            BEDOK MRT STATION (EW5)  103.929984495066
# 145                       TOA PAYOH MRT STATION (NS19)  103.847502198048
# 146                        BOON KENG MRT STATION (NE9)  103.861569454156
# 147                        TAI SENG MRT STATION (CC11)  103.888389300191
# 148                   GEYLANG BAHRU MRT STATION (DT24)  103.871622627142
# 149                    POTONG PASIR MRT STATION (NE10)  103.869055656782
# 150                       WOODLEIGH MRT STATION (NE11)   103.87081830915
# 151                          MATTAR MRT STATION (DT25)  103.883247509542
# 152                        MAYFLOWER MRT STATION (TE6)  103.836567766945
# 153                        KEMBANGAN MRT STATION (EW6)  103.912947930851
# 154                     KATONG PARK MRT STATION (TE24)  103.886178949925
# 155                      TANAH MERAH MRT STATION (EW4)  103.946348600798
# 156                     BEDOK SOUTH MRT STATION (TE30)   103.94931120983
# 157                     BEDOK NORTH MRT STATION (DT29)   103.91797832995
# 158                    UPPER CHANGI MRT STATION (DT34)  103.961472788634
# 159                     BUKIT GOMBAK MRT STATION (NS3)  103.751790910733
# 160                         HILLVIEW MRT STATION (DT3)  103.767418254007
# 161                           KOVAN MRT STATION (NE13)  103.885064856353
# 162                       SERANGOON MRT STATION (NE12)  103.873574849884
# 163                         HOUGANG MRT STATION (NE14)  103.892380513029
# 164                         BARTLEY MRT STATION (CC12)  103.880177899184
# 165                       MARYMOUNT MRT STATION (CC16)  103.839423132332
# 166                          YEW TEE MRT STATION (NS5)  103.747405150236
# 167                        JOO KOON MRT STATION (EW29)  103.678374996165
# 168                      GUL CIRCLE MRT STATION (EW30)  103.660530461345
# 169                   TUAS CRESCENT MRT STATION (EW31)  103.649078235627
# 170                    BUKIT PANJANG MRT STATION (DT1)  103.761535114929
# 171                       ADMIRALTY MRT STATION (NS10)  103.800990519771
# 172                   CHANGI AIRPORT MRT STATION (CG2)   103.98788356959
# 173                         PUNGGOL MRT STATION (NE17)  103.902072622229
# 174                           KRANJI MRT STATION (NS7)  103.762137459497
# 175                       SPRINGLEAF MRT STATION (TE4)  103.817856949947
# 176                       WOODLANDS MRT STATION EXIT 1   103.78584424633
# 177                 WOODLANDS NORTH MRT STATION EXIT 1  103.785442208175
# 178                 WOODLANDS SOUTH MRT STATION EXIT 1  103.792905880804
# 179                       WOODLANDS MRT STATION EXIT 2  103.786393694452
# 180                 WOODLANDS NORTH MRT STATION EXIT 2  103.785105159941
# 181                 WOODLANDS SOUTH MRT STATION EXIT 2  103.793306545734
# 182                       WOODLANDS MRT STATION EXIT 3  103.787224897942
# 183                 WOODLANDS SOUTH MRT STATION EXIT 3  103.794630237029
# 184                       WOODLANDS MRT STATION EXIT 4  103.786982831894
# 185                 WOODLANDS SOUTH MRT STATION EXIT 4  103.794557997153
# 186                       WOODLANDS MRT STATION EXIT 5  103.788988127958
# 187                 WOODLANDS SOUTH MRT STATION EXIT 5  103.794395983627
# 188                       WOODLANDS MRT STATION EXIT 6  103.789090551552
# 189                       WOODLANDS MRT STATION EXIT 7  103.787996783139
# 190                       CITY HALL MRT STATION EXIT A  103.853021562271
# 191             CITY HALL/ESPLANADE MRT STATION EXIT A  103.854609475029
# 192                     CLARKE QUAY MRT STATION EXIT A  103.846064544116
# 193                        CLEMENTI MRT STATION EXIT A  103.764982679711
# 194                    COMMONWEALTH MRT STATION EXIT A  103.797958291874
# 195                          DAKOTA MRT STATION EXIT A  103.889298048161
# 196                     DHOBY GHAUT MRT STATION EXIT A  103.846779253533
# 197                           DOVER MRT STATION EXIT A  103.778294380083
# 198                        DOWNTOWN MRT STATION EXIT A  103.852644319125
# 199                       ESPLANADE MRT STATION EXIT A  103.856303258535
# 200                           EUNOS MRT STATION EXIT A  103.902894137829
# 201                            EXPO MRT STATION EXIT A  103.961942958225
# 202                     FARRER PARK MRT STATION EXIT A  103.854770359677
# 203                     FARRER ROAD MRT STATION EXIT A   103.80796658755
# 204                       BENCOOLEN MRT STATION EXIT A  103.850838318577
# 205                       BENDEMEER MRT STATION EXIT A  103.863062802793
# 206                          BISHAN MRT STATION EXIT A   103.84830499183
# 207                       BOON KENG MRT STATION EXIT A  103.861504484655
# 208                        BOON LAY MRT STATION EXIT A  103.705405450881
# 209                 BOTANIC GARDENS MRT STATION EXIT A  103.814976905867
# 210                        BRADDELL MRT STATION EXIT A  103.846411762858
# 211                      BRAS BASAH MRT STATION EXIT A  103.851321219873
# 212                        BUANGKOK MRT STATION EXIT A  103.892867735131
# 213                           BUGIS MRT STATION EXIT A  103.855924081071
# 214                     BUKIT BATOK MRT STATION EXIT A   103.74997014583
# 215                    BUKIT GOMBAK MRT STATION EXIT A  103.752067334531
# 216                     BUONA VISTA MRT STATION EXIT A  103.790448798318
# 217                       CALDECOTT MRT STATION EXIT A  103.839817353297
# 218                        CANBERRA MRT STATION EXIT A  103.829452068775
# 219                          CASHEW MRT STATION EXIT A  103.764207873199
# 220                  CHANGI AIRPORT MRT STATION EXIT A  103.989276642386
# 221                       ADMIRALTY MRT STATION EXIT A  103.800984160903
# 222                        ALJUNIED MRT STATION EXIT A  103.882496650859
# 223                      ANG MO KIO MRT STATION EXIT A  103.849939000494
# 224                         BARTLEY MRT STATION EXIT A   103.88038311704
# 225                        BAYFRONT MRT STATION EXIT A  103.858901011605
# 226                    BEAUTY WORLD MRT STATION EXIT A   103.77597845088
# 227                           BEDOK MRT STATION EXIT A   103.92915714301
# 228                     BEDOK NORTH MRT STATION EXIT A  103.918038975838
# 229                 BEDOK RESERVOIR MRT STATION EXIT A  103.932853678147
# 230                       CHINATOWN MRT STATION EXIT A  103.843753409155
# 231                  CHINESE GARDEN MRT STATION EXIT A  103.732224636444
# 232                   CHOA CHU KANG MRT STATION EXIT A  103.744556001885
# 233                     MOUNTBATTEN MRT STATION EXIT A  103.882606383464
# 234                          NEWTON MRT STATION EXIT A  103.837887180414
# 235                  NICOLL HIGHWAY MRT STATION EXIT A  103.863504714405
# 236                         STADIUM MRT STATION EXIT A  103.874399988354
# 237                         STEVENS MRT STATION EXIT A  103.825684307354
# 238                        TAI SENG MRT STATION EXIT A  103.887631743289
# 239                   TAMPINES EAST MRT STATION EXIT A  103.954540107876
# 240                        TAMPINES MRT STATION EXIT A  103.944766312114
# 241                   TAMPINES WEST MRT STATION EXIT A  103.938180857761
# 242                     TAN KAH KEE MRT STATION EXIT A  103.807798268409
# 243                     TANAH MERAH MRT STATION EXIT A  103.945791448865
# 244                   TANJONG PAGAR MRT STATION EXIT A  103.844820544637
# 245                    LITTLE INDIA MRT STATION EXIT A  103.849351642577
# 246                    LORONG CHUAN MRT STATION EXIT A  103.864928562503
# 247                      MACPHERSON MRT STATION EXIT A  103.889785899423
# 248                      MARINA BAY MRT STATION EXIT A  103.854837896688
# 249               MARINA SOUTH PIER MRT STATION EXIT A  103.862280576826
# 250                       MARSILING MRT STATION EXIT A  103.774206739388
# 251                       MARYMOUNT MRT STATION EXIT A  103.839088041822
# 252                          MATTAR MRT STATION EXIT A  103.882737801185
# 253                       SERANGOON MRT STATION EXIT A  103.873953722359
# 254                           SIMEI MRT STATION EXIT A  103.953820143851
# 255                    SIXTH AVENUE MRT STATION EXIT A  103.796556228194
# 256                        SOMERSET MRT STATION EXIT A  103.838385643936
# 257                    FORT CANNING MRT STATION EXIT A  103.844157466584
# 258                   GEYLANG BAHRU MRT STATION EXIT A  103.871560444143
# 259                      GUL CIRCLE MRT STATION EXIT A  103.660791651785
# 260                    HARBOURFRONT MRT STATION EXIT A  103.820474550192
# 261                   HAW PAR VILLA MRT STATION EXIT A  103.782000217778
# 262                        HILLVIEW MRT STATION EXIT A  103.767689699531
# 263                 HOLLAND VILLAGE MRT STATION EXIT A   103.79613442284
# 264                       SEMBAWANG MRT STATION EXIT A  103.820110302142
# 265                        SENGKANG MRT STATION EXIT A  103.895405721181
# 266                         HOUGANG MRT STATION EXIT A  103.892440505123
# 267                     JALAN BESAR MRT STATION EXIT A  103.855292545514
# 268                        JOO KOON MRT STATION EXIT A   103.67852468431
# 269                     JURONG EAST MRT STATION EXIT A  103.741735118735
# 270                      KAKI BUKIT MRT STATION EXIT A  103.909406099681
# 271                         KALLANG MRT STATION EXIT A   103.87173056453
# 272                       KEMBANGAN MRT STATION EXIT A  103.912940025483
# 273                      KENT RIDGE MRT STATION EXIT A  103.784465461468
# 274                          KHATIB MRT STATION EXIT A  103.832952685091
# 275                KING ALBERT PARK MRT STATION EXIT A  103.783018890137
# 276                           KOVAN MRT STATION EXIT A  103.884302648859
# 277                          KRANJI MRT STATION EXIT A  103.762018327024
# 278                   LABRADOR PARK MRT STATION EXIT A    103.8023606392
# 279                        LAKESIDE MRT STATION EXIT A  103.720437685172
# 280                        LAVENDER MRT STATION EXIT A  103.863043062595
# 281                          NOVENA MRT STATION EXIT A  103.844405791263
# 282                       ONE-NORTH MRT STATION EXIT A  103.786896776117
# 283                         ORCHARD MRT STATION EXIT A  103.832525108319
# 284                     OUTRAM PARK MRT STATION EXIT A  103.838652479817
# 285                   PASIR PANJANG MRT STATION EXIT A  103.792033824349
# 286                       PASIR RIS MRT STATION EXIT A   103.94933342667
# 287                      PAYA LEBAR MRT STATION EXIT A  103.892791663683
# 288                         PIONEER MRT STATION EXIT A  103.697143068046
# 289                    POTONG PASIR MRT STATION EXIT A  103.868967364441
# 290                       PROMENADE MRT STATION EXIT A  103.860648429929
# 291                         PUNGGOL MRT STATION EXIT A  103.902277867411
# 292                      QUEENSTOWN MRT STATION EXIT A  103.806179465908
# 293                   RAFFLES PLACE MRT STATION EXIT A  103.851438353944
# 294                         REDHILL MRT STATION EXIT A  103.816997605512
# 295                          ROCHOR MRT STATION EXIT A   103.85265283045
# 296                      TELOK AYER MRT STATION EXIT A  103.848512874679
# 297                   TELOK BLANGAH MRT STATION EXIT A  103.809884576279
# 298                     TIONG BAHRU MRT STATION EXIT A  103.826996837921
# 299                       TOA PAYOH MRT STATION EXIT A  103.847723804246
# 300                   TUAS CRESCENT MRT STATION EXIT A   103.64900720771
# 301                       TUAS LINK MRT STATION EXIT A  103.637249681748
# 302                  TUAS WEST ROAD MRT STATION EXIT A  103.639299528273
# 303                             UBI MRT STATION EXIT A  103.899869894436
# 304                    UPPER CHANGI MRT STATION EXIT A  103.961328545289
# 305                       WOODLEIGH MRT STATION EXIT A  103.870937707986
# 306                         YEE TEE MRT STATION EXIT A    103.7471891227
# 307                    YIO CHU KANG MRT STATION EXIT A  103.844821034472
# 308                          YISHUN MRT STATION EXIT A  103.834790629506
# 309                  BUKIT PANJANG MRT STATION EXIT A1  103.761921007838
# 310                  BUKIT PANJANG MRT STATION EXIT A2  103.762039889143
# 311                       ADMIRALTY MRT STATION EXIT B  103.800527184397
# 312                       ADMIRALTY MRT STATION EXIT C  103.800551474686
# 313                       ADMIRALTY MRT STATION EXIT D  103.801364534318
# 314                  CHANGI AIRPORT MRT STATION EXIT B  103.987304579993
# 315                KING ALBERT PARK MRT STATION EXIT B   103.78360641226
# 316                        ALJUNIED MRT STATION EXIT B  103.882472888012
# 317                      ANG MO KIO MRT STATION EXIT B  103.849582687035
# 318                      ANG MO KIO MRT STATION EXIT C  103.849334379134
# 319                      ANG MO KIO MRT STATION EXIT D  103.849825701795
# 320                    SIXTH AVENUE MRT STATION EXIT B  103.796828207439
# 321                      TELOK AYER MRT STATION EXIT B  103.848767031399
# 322                      TELOK AYER MRT STATION EXIT C  103.848846121797
# 323                       CITY HALL MRT STATION EXIT B  103.851951129481
# 324             CITY HALL/ESPLANADE MRT STATION EXIT B  103.854756044222
# 325                     CLARKE QUAY MRT STATION EXIT B  103.845907275918
# 326                        CLEMENTI MRT STATION EXIT B  103.765155477484
# 327                    COMMONWEALTH MRT STATION EXIT B  103.798055145187
# 328                          DAKOTA MRT STATION EXIT B   103.88796919827
# 329                     DHOBY GHAUT MRT STATION EXIT B  103.845225625047
# 330                           DOVER MRT STATION EXIT B  103.778446601688
# 331                        DOWNTOWN MRT STATION EXIT B  103.852915339847
# 332                       ESPLANADE MRT STATION EXIT B  103.856172105283
# 333                           EUNOS MRT STATION EXIT B   103.90258207739
# 334                            EXPO MRT STATION EXIT B  103.962070158326
# 335                     FARRER PARK MRT STATION EXIT B  103.854738296374
# 336                     FARRER ROAD MRT STATION EXIT B  103.807384282049
# 337                       BENCOOLEN MRT STATION EXIT B   103.84958461668
# 338                       BENDEMEER MRT STATION EXIT B  103.863213831657
# 339                          BISHAN MRT STATION EXIT B   103.84831225604
# 340                       BOON KENG MRT STATION EXIT B   103.86189339355
# 341                        BOON LAY MRT STATION EXIT B  103.706145548038
# 342                 BOTANIC GARDENS MRT STATION EXIT B  103.815911233166
# 343                        BRADDELL MRT STATION EXIT B  103.846393244977
# 344                      BRAS BASAH MRT STATION EXIT B  103.850473380875
# 345                        BUANGKOK MRT STATION EXIT B  103.893463151692
# 346                           BUGIS MRT STATION EXIT B  103.856327844038
# 347                     BUKIT BATOK MRT STATION EXIT B  103.749966157866
# 348                    BUKIT GOMBAK MRT STATION EXIT B  103.752084995437
# 349                   BUKIT PANJANG MRT STATION EXIT B   103.76135235089
# 350                     BUONA VISTA MRT STATION EXIT B  103.790656619025
# 351                       CALDECOTT MRT STATION EXIT B  103.839401106536
# 352                        CANBERRA MRT STATION EXIT B  103.830304623338
# 353                         BARTLEY MRT STATION EXIT B  103.878909070836
# 354                        BAYFRONT MRT STATION EXIT B  103.859759179874
# 355                    BEAUTY WORLD MRT STATION EXIT B  103.775457793003
# 356                           BEDOK MRT STATION EXIT B  103.929673090102
# 357                     BEDOK NORTH MRT STATION EXIT B  103.919055366359
# 358                 BEDOK RESERVOIR MRT STATION EXIT B  103.933489354839
# 359                  CHINESE GARDEN MRT STATION EXIT B  103.732414798591
# 360                   CHOA CHU KANG MRT STATION EXIT B  103.744591903712
# 361                     MOUNTBATTEN MRT STATION EXIT B  103.883248292795
# 362                          NEWTON MRT STATION EXIT B  103.838211803447
# 363                  NICOLL HIGHWAY MRT STATION EXIT B  103.864164402932
# 364                         STADIUM MRT STATION EXIT B  103.876226233523
# 365                        TAI SENG MRT STATION EXIT B  103.888276517231
# 366                   TAMPINES EAST MRT STATION EXIT B  103.955182879925
# 367                        TAMPINES MRT STATION EXIT B  103.945089563391
# 368                   TAMPINES WEST MRT STATION EXIT B  103.938956764542
# 369                     TAN KAH KEE MRT STATION EXIT B  103.807782858593
# 370                     TANAH MERAH MRT STATION EXIT B  103.945723128534
# 371                   TANJONG PAGAR MRT STATION EXIT B  103.846554745658
# 372                    LITTLE INDIA MRT STATION EXIT B  103.848983594397
# 373                    LORONG CHUAN MRT STATION EXIT B   103.86291944158
# 374                      MACPHERSON MRT STATION EXIT B  103.890662826068
# 375                      MARINA BAY MRT STATION EXIT B  103.854259831252
# 376               MARINA SOUTH PIER MRT STATION EXIT B  103.863564370201
# 377                       MARSILING MRT STATION EXIT B  103.774404548397
# 378                       MARYMOUNT MRT STATION EXIT B  103.840047785068
# 379                          MATTAR MRT STATION EXIT B  103.883740474769
# 380                       SERANGOON MRT STATION EXIT B   103.87364078459
# 381                        SOMERSET MRT STATION EXIT B  103.838454758569
# 382                    FORT CANNING MRT STATION EXIT B   103.84441386951
# 383                   GEYLANG BAHRU MRT STATION EXIT B  103.871784960916
# 384                      GUL CIRCLE MRT STATION EXIT B  103.659476020414
# 385                    HARBOURFRONT MRT STATION EXIT B  103.820492064514
# 386                        HILLVIEW MRT STATION EXIT B  103.767088008608
# 387                 HOLLAND VILLAGE MRT STATION EXIT B  103.795769657083
# 388                       SEMBAWANG MRT STATION EXIT B  103.819783211843
# 389                        SENGKANG MRT STATION EXIT B   103.89563689476
# 390                         HOUGANG MRT STATION EXIT B  103.892967209174
# 391                     JALAN BESAR MRT STATION EXIT B  103.855237082044
# 392                        JOO KOON MRT STATION EXIT B  103.678641427081
# 393                     JURONG EAST MRT STATION EXIT B  103.742643110659
# 394                      KAKI BUKIT MRT STATION EXIT B  103.908996040609
# 395                         KALLANG MRT STATION EXIT B  103.871587075702
# 396                       KEMBANGAN MRT STATION EXIT B  103.912899289031
# 397                      KENT RIDGE MRT STATION EXIT B  103.784829341664
# 398                          KHATIB MRT STATION EXIT B  103.832691768658
# 399                           KOVAN MRT STATION EXIT B  103.884723781231
# 400                          KRANJI MRT STATION EXIT B   103.76193427334
# 401                        LAKESIDE MRT STATION EXIT B  103.721063264468
# 402                        LAVENDER MRT STATION EXIT B  103.862650316842
# 403                          NOVENA MRT STATION EXIT B  103.843322866691
# 404                       ONE-NORTH MRT STATION EXIT B  103.787924549354
# 405                         ORCHARD MRT STATION EXIT B  103.832171601288
# 406                     OUTRAM PARK MRT STATION EXIT B  103.838934837349
# 407                       PASIR RIS MRT STATION EXIT B  103.949136940627
# 408                      PAYA LEBAR MRT STATION EXIT B  103.892208157793
# 409                         PIONEER MRT STATION EXIT B  103.697131949809
# 410                    POTONG PASIR MRT STATION EXIT B  103.869326795079
# 411                       PROMENADE MRT STATION EXIT B  103.860131090003
# 412                         PUNGGOL MRT STATION EXIT B  103.902636298374
# 413                      QUEENSTOWN MRT STATION EXIT B  103.806357110237
# 414                   RAFFLES PLACE MRT STATION EXIT B  103.851479977962
# 415                         REDHILL MRT STATION EXIT B  103.817249373128
# 416                          ROCHOR MRT STATION EXIT B  103.853030813143
# 417                     TIONG BAHRU MRT STATION EXIT B  103.827494927199
# 418                       TOA PAYOH MRT STATION EXIT B  103.847557800613
# 419                   TUAS CRESCENT MRT STATION EXIT B  103.649354280675
# 420                       TUAS LINK MRT STATION EXIT B  103.636664841468
# 421                  TUAS WEST ROAD MRT STATION EXIT B  103.639813026933
# 422                             UBI MRT STATION EXIT B  103.898581927079
# 423                    UPPER CHANGI MRT STATION EXIT B  103.961458853982
# 424                       WOODLEIGH MRT STATION EXIT B  103.870506498272
# 425                         YEE TEE MRT STATION EXIT B  103.747330414399
# 426                    YIO CHU KANG MRT STATION EXIT B  103.844952857705
# 427                          YISHUN MRT STATION EXIT B  103.834867077043
# 428                      BRAS BASAH MRT STATION EXIT C  103.850254660057
# 429                      BRAS BASAH MRT STATION EXIT D  103.850162603062
# 430                      BRAS BASAH MRT STATION EXIT E  103.850424728146
# 431                     BUKIT BATOK MRT STATION EXIT C  103.749769199779
# 432                     BUKIT BATOK MRT STATION EXIT D  103.749126361849
# 433                          BAYFRONT MRT STATION EXIT  103.861170309768
# 434                        BAYFRONT MRT STATION EXIT C  103.859596872464
# 435                        BAYFRONT MRT STATION EXIT D  103.859493846293
# 436                        BAYFRONT MRT STATION EXIT E  103.858419290212
# 437                    BEAUTY WORLD MRT STATION EXIT C  103.775739691571
# 438                           BEDOK MRT STATION EXIT C  103.929397331362
# 439                     BEDOK NORTH MRT STATION EXIT C  103.917795887643
# 440                       BENCOOLEN MRT STATION EXIT C  103.849792402967
# 441                          BISHAN MRT STATION EXIT C  103.848209280992
# 442                          BISHAN MRT STATION EXIT D  103.850201082237
# 443                          BISHAN MRT STATION EXIT E  103.848432923358
# 444                       BOON KENG MRT STATION EXIT C  103.860696261122
# 445                        BOON LAY MRT STATION EXIT C  103.705955424998
# 446                        BOON LAY MRT STATION EXIT D   103.70564279661
# 447                        BOON LAY MRT STATION EXIT E  103.705349474637
# 448                        BOON LAY MRT STATION EXIT F  103.705790413341
# 449                        BRADDELL MRT STATION EXIT C  103.847430767853
# 450                       BUKIT BROWN MRT STATION EXIT   103.82962180333
# 451                    BUKIT GOMBAK MRT STATION EXIT C  103.751726614973
# 452                    BUKIT GOMBAK MRT STATION EXIT D  103.751948590322
# 453                           BUGIS MRT STATION EXIT C  103.855680462892
# 454                           BUGIS MRT STATION EXIT D  103.856888176117
# 455                     BUONA VISTA MRT STATION EXIT C  103.790587853553
# 456                     BUONA VISTA MRT STATION EXIT D  103.790915022568
# 457                       CITY HALL MRT STATION EXIT C  103.852985301431
# 458             CITY HALL/ESPLANADE MRT STATION EXIT C  103.855192585584
# 459                      CLARK QUAY MRT STATION EXIT C   103.84667577547
# 460                        CLEMENTI MRT STATION EXIT C  103.765773642566
# 461                    COMMONWEALTH MRT STATION EXIT C  103.798768241331
# 462                     DHOBY GHAUT MRT STATION EXIT C    103.8447478575
# 463                        DOWNTOWN MRT STATION EXIT C  103.853157831883
# 464                       ESPLANADE MRT STATION EXIT C  103.855853127614
# 465                           EUNOS MRT STATION EXIT C  103.903178612002
# 466                            EXPO MRT STATION EXIT C  103.962162221687
# 467                     FARRER PARK MRT STATION EXIT C  103.853252685538
# 468                        CANBERRA MRT STATION EXIT C  103.829824358977
# 469                       CHINATOWN MRT STATION EXIT C  103.842825779347
# 470                  CHINESE GARDEN MRT STATION EXIT C   103.73266879526
# 471                   CHOA CHU KANG MRT STATION EXIT C  103.744203030367
# 472                          NEWTON MRT STATION EXIT C  103.838250349066
# 473                        TAI SENG MRT STATION EXIT C  103.888554708543
# 474                   TAMPINES EAST MRT STATION EXIT C  103.955705279032
# 475                        TAMPINES MRT STATION EXIT C  103.944903957552
# 476                   TANJONG PAGAR MRT STATION EXIT C  103.846529873368
# 477                    LITTLE INDIA MRT STATION EXIT C  103.849699817435
# 478                      MACPHERSON MRT STATION EXIT C  103.890256223937
# 479                       MARSILING MRT STATION EXIT C  103.773821235261
# 480                       SERANGOON MRT STATION EXIT C  103.873700895063
# 481                        SOMERSET MRT STATION EXIT C  103.838763820601
# 482                    HARBOURFRONT MRT STATION EXIT C  103.822518543831
# 483                 HOLLAND VILLAGE MRT STATION EXIT C  103.795744343131
# 484                       SEMBAWANG MRT STATION EXIT C  103.819762177164
# 485                        SENGKANG MRT STATION EXIT C  103.895209399306
# 486                         HOUGANG MRT STATION EXIT C  103.891962218579
# 487                     JURONG EAST MRT STATION EXIT C  103.742753602536
# 488                      KENT RIDGE MRT STATION EXIT C  103.784464941237
# 489                          KHATIB MRT STATION EXIT C  103.832849099942
# 490                           KOVAN MRT STATION EXIT C   103.88542633438
# 491                          KRANJI MRT STATION EXIT C  103.761754685801
# 492                        LAKESIDE MRT STATION EXIT C    103.7217171276
# 493                       ONE-NORTH MRT STATION EXIT C  103.787565456114
# 494                         ORCHARD MRT STATION EXIT C  103.832619611937
# 495                     OUTRAM PARK MRT STATION EXIT C   103.83936176296
# 496                      PAYA LEBAR MRT STATION EXIT C  103.891714062796
# 497                    POTONG PASIR MRT STATION EXIT C  103.868704125473
# 498                       PROMENADE MRT STATION EXIT C  103.860219019476
# 499                         PUNGGOL MRT STATION EXIT C  103.902137628909
# 500                      QUEENSTOWN MRT STATION EXIT C  103.805590387127
# 501                   RAFFLES PLACE MRT STATION EXIT C  103.851590024488
# 502                       TOA PAYOH MRT STATION EXIT C  103.847318436474
# 503                    UPPER CHANGI MRT STATION EXIT C  103.961625359424
# 504                       WOODLEIGH MRT STATION EXIT C  103.871060782466
# 505                         YEE TEE MRT STATION EXIT C  103.747431893505
# 506                    YIO CHU KANG MRT STATION EXIT C  103.844651533361
# 507                          YISHUN MRT STATION EXIT C  103.835123644577
# 508                    COMMONWEALTH MRT STATION EXIT D  103.798714315911
# 509                        CANBERRA MRT STATION EXIT D   103.82909543666
# 510                        CANBERRA MRT STATION EXIT E  103.830409234978
# 511                    UPPER CHANGI MRT STATION EXIT D  103.961040578956
# 512                       CHINATOWN MRT STATION EXIT D  103.843476210331
# 513                       CHINATOWN MRT STATION EXIT E  103.844426948683
# 514                       CHINATOWN MRT STATION EXIT F  103.845467224043
# 515                       CHINATOWN MRT STATION EXIT G  103.844469740517
# 516                   CHOA CHU KANG MRT STATION EXIT D  103.744509334035
# 517             CITY HALL/ESPLANADE MRT STATION EXIT D  103.855100997965
# 518             CITY HALL/ESPLANADE MRT STATION EXIT E  103.854835837712
# 519                      CLARK QUAY MRT STATION EXIT E  103.847034118586
# 520                      CLARK QUAY MRT STATION EXIT G  103.846585433629
# 521                     CLARKE QUAY MRT STATION EXIT F  103.847114861345
# 522                        CLEMENTI MRT STATION EXIT D  103.765541409161
# 523                     DHOBY GHAUT MRT STATION EXIT D  103.845030131943
# 524                        DOWNTOWN MRT STATION EXIT D  103.853011532212
# 525                       ESPLANADE MRT STATION EXIT D  103.855838027673
# 526                            EXPO MRT STATION EXIT D  103.963094416433
# 527                     FARRER PARK MRT STATION EXIT D  103.852972884828
# 528                   TAMPINES EAST MRT STATION EXIT D  103.955705018523
# 529                        TAMPINES MRT STATION EXIT D   103.94366545104
# 530                   TANJONG PAGAR MRT STATION EXIT D   103.84689166529
# 531                    LITTLE INDIA MRT STATION EXIT D  103.849036656915
# 532                      MACPHERSON MRT STATION EXIT D  103.888441983492
# 533                       MARSILING MRT STATION EXIT D  103.773981720213
# 534                       SERANGOON MRT STATION EXIT D  103.874316461685
# 535                        SOMERSET MRT STATION EXIT D  103.839744499851
# 536                    HARBOURFRONT MRT STATION EXIT D  103.821395893674
# 537                       SEMBAWANG MRT STATION EXIT D  103.820401560553
# 538                        SENGKANG MRT STATION EXIT D  103.895735075793
# 539                     JURONG EAST MRT STATION EXIT D  103.742292350324
# 540                      KENT RIDGE MRT STATION EXIT D  103.784528751623
# 541                          KHATIB MRT STATION EXIT D  103.833171755256
# 542                          KRANJI MRT STATION EXIT D  103.762492227566
# 543                       ONE-NORTH MRT STATION EXIT D  103.787788925371
# 544                         ORCHARD MRT STATION EXIT D   103.83277034807
# 545                     OUTRAM PARK MRT STATION EXIT D  103.839417926793
# 546                      PAYA LEBAR MRT STATION EXIT D  103.892080103557
# 547                         PUNGGOL MRT STATION EXIT D  103.901779196308
# 548                      QUEENSTOWN MRT STATION EXIT D  103.805476932015
# 549                   RAFFLES PLACE MRT STATION EXIT D  103.851353214777
# 550                       TOA PAYOH MRT STATION EXIT D  103.846517405644
# 551                         YEE TEE MRT STATION EXIT D  103.747110207103
# 552                          YISHUN MRT STATION EXIT D  103.834865759456
# 553                     DHOBY GHAUT MRT STATION EXIT E  103.845372294004
# 554                     DHOBY GHAUT MRT STATION EXIT F  103.845842317726
# 555                          DOWNTOWN MRT STATION EXIT  103.852236529778
# 556                        DOWNTOWN MRT STATION EXIT E  103.852449812084
# 557                        DOWNTOWN MRT STATION EXIT F   103.85242031201
# 558                       ESPLANADE MRT STATION EXIT E  103.855564111142
# 559                            EXPO MRT STATION EXIT E  103.962127196209
# 560                     FARRER PARK MRT STATION EXIT E  103.852635074799
# 561                        TAMPINES MRT STATION EXIT E  103.942653448012
# 562                   TANJONG PAGAR MRT STATION EXIT E  103.847102135241
# 563                    LITTLE INDIA MRT STATION EXIT E  103.850319624488
# 564                      MACPHERSON MRT STATION EXIT E  103.888602871376
# 565                       SERANGOON MRT STATION EXIT E  103.872900878668
# 566                    HARBOURFRONT MRT STATION EXIT E  103.821580291341
# 567                         ORCHARD MRT STATION EXIT E  103.832039800868
# 568                     OUTRAM PARK MRT STATION EXIT E  103.839778718686
# 569                   RAFFLES PLACE MRT STATION EXIT E  103.851522595561
# 570                          YISHUN MRT STATION EXIT E   103.83564365509
# ...
# 217  1.33783133391774
# 218  1.44378209457473
# 219  1.36984438594547
# 220  1.35634142135844
# 221  1.44034337155074
# 222  1.31623848507352
# 223  1.36946470665767
# 224  1.34225958353607
# 225  1.28127519755786
# 226  1.34169768144374
# 227  1.32356863626393
# 228  1.33516634096411
# 229  1.33635797475902
# 230  1.28373507204208
# 231  1.34244084264959
# 232  1.38542620120991
# 233  1.30676211145182
# 234  1.31260401136518
# 235  1.30017456235547
# 236   1.3025110879373
# 237  1.32032920290987
# 238  1.33591983565073
# 239  1.35646289026058
# 240  1.35376401277764
# 241  1.34564366435243
# 242  1.32532796917374
# 243  1.32686509987036
# 244  1.27639874607446
# 245  1.30561418181496
# 246  1.35143709131033
# 247  1.32668882024017
# 248  1.27569680010441
# 249  1.27067523469027
# 250  1.43280792459597
# 251   1.3489799079699
# 252  1.32725878626358
# 253  1.34948283498049
# 254  1.34265578602279
# 255  1.33077316862752
# 256  1.30003194313604
# 257  1.29241261624443
# 258  1.32156657295526
# 259  1.31927858114204
# 260  1.26601026056903
# 261  1.28306622750313
# 262  1.36249753291868
# 263  1.31122356458793
# 264  1.44883562841554
# 265  1.39182911978883
# 266  1.37017281190245
# 267  1.30489011626895
# 268  1.32750377971587
# 269  1.33400861029635
# 270  1.33532217853623
# 271  1.31154048337102
# 272  1.32092967329613
# 273  1.29431784777384
# 702          BUONA VISTA   103.790363200126  1.30627534823257
# 715            CITY HALL   103.852542630339  1.29298990700923
# 717         LORONG CHUAN   103.864812169514  1.35153128621585
# 724          TIONG BAHRU   103.826998939732  1.28619457890544
# 727               BISHAN   103.850057208608  1.35101889777844
# 731           MACPHERSON   103.890007860464  1.32683963232487
# 734                BUGIS   103.855614760658  1.30026468984101
# 736                BUGIS   103.855706731205   1.3004650853709
# 766               DAKOTA   103.889268208422  1.30843144331463
# 772             LAVENDER   103.862784610013  1.30739187893137
# 773            SERANGOON   103.871070417199   1.3510482896351
# 775          FARRER PARK   103.854754721344  1.31314029963164
# 779               NEWTON   103.838031555215  1.31257031730604
# 782         LITTLE INDIA   103.850093622794  1.30769844708108
# 792           ANG MO KIO   103.849558091776  1.36993284962264
# 798          TAN KAH KEE   103.806548201692  1.32639224146351
# 799         SIXTH AVENUE   103.796969279733  1.33096058134451
# 801            CALDECOTT   103.839544077561  1.33734722320212
# 820          MOUNTBATTEN   103.883045148696  1.30615406128913
# 832            BOON KENG   103.862052698446  1.31993957653291
# 837         POTONG PASIR   103.869363547741  1.33137808528793
# 839            WOODLEIGH    103.87096088798  1.33982824592182
# 849             HILLVIEW   103.767780907707  1.36288845715168
# 852                KOVAN   103.884494725197  1.35990191952976
# 859              HOUGANG   103.892261757937  1.37033472429161
# 861              BARTLEY   103.880197087117   1.3424454382925
# 873        BUKIT PANJANG   103.761188866252  1.37956121236613

# %%
mrt.drop_duplicates(subset='mrt_station', inplace=True)
# Out:
# C:\Users\caspe\anaconda3\envs\capstone\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
mrt = mrt.sort_values(by='mrt station')

# %%
mrt.shape
# Out:
# (155, 3)

# %%
mrt['longitude'] = mrt['longitude'].astype(float)
mrt['latitude'] = mrt['latitude'].astype(float)

# %%
mrt.index = np.arange(len(mrt))

# %%
mrt.to_csv('../datasets/amenities/mrt_cleaned.csv', index=False)

# %% [markdown]
# ## Scraping Pri Sch coordinates

# %%
pri_sch = get_amenities('primary school', 25, 'df_pri_sch', 'primary_school')
# Out:
# Retrieved Page1 for primary school Coordinates
# Retrieved Page2 for primary school Coordinates
# Retrieved Page3 for primary school Coordinates
# Retrieved Page4 for primary school Coordinates
# Retrieved Page5 for primary school Coordinates
# Retrieved Page6 for primary school Coordinates
# Retrieved Page7 for primary school Coordinates
# Retrieved Page8 for primary school Coordinates
# Retrieved Page9 for primary school Coordinates
# Retrieved Page10 for primary school Coordinates
# Retrieved Page11 for primary school Coordinates
# Retrieved Page12 for primary school Coordinates
# Retrieved Page13 for primary school Coordinates
# Retrieved Page14 for primary school Coordinates
# Retrieved Page15 for primary school Coordinates
# Retrieved Page16 for primary school Coordinates
# Retrieved Page17 for primary school Coordinates
# Retrieved Page18 for primary school Coordinates
# Retrieved Page19 for primary school Coordinates
# Retrieved Page20 for primary school Coordinates
# Retrieved Page21 for primary school Coordinates
# Retrieved Page22 for primary school Coordinates
# Retrieved Page23 for primary school Coordinates
# Retrieved Page24 for primary school Coordinates
# Retrieved Page25 for primary school Coordinates
#                                         primary school         longitude  \
# 0                              ZHONGHUA PRIMARY SCHOOL  103.869762438084
# 1                              ZHENGHUA PRIMARY SCHOOL  103.769313521752
# 2                               ZHANGDE PRIMARY SCHOOL  103.825951875662
# 3                                 YUMIN PRIMARY SCHOOL  103.950461927088
# 4                                 YUHUA PRIMARY SCHOOL  103.741105772644
# 5                               YU NENG PRIMARY SCHOOL  103.932144857355
# 6                                JIEMIN PRIMARY SCHOOL  103.830425490093
# 7                                XISHAN PRIMARY SCHOOL  103.837755319448
# 8                         AHMAD IBRAHIM PRIMARY SCHOOL  103.832942401086
# 9                                YISHUN PRIMARY SCHOOL  103.834087115915
# 10                              PEIYING PRIMARY SCHOOL  103.830417090698
# 11                           NORTH VIEW PRIMARY SCHOOL  103.848190787869
# 12                            NORTHLAND PRIMARY SCHOOL  103.840928424929
# 13                           NAVAL BASE PRIMARY SCHOOL  103.838794077233
# 14                               HUAMIN PRIMARY SCHOOL  103.844240226564
# 15                         YIO CHU KANG PRIMARY SCHOOL  103.885643682171
# 16                              YEW TEE PRIMARY SCHOOL  103.750985967346
# 17                            YANGZHENG PRIMARY SCHOOL  103.868595527042
# 18                               XINMIN PRIMARY SCHOOL  103.883080767491
# 19                              XINGNAN PRIMARY SCHOOL  103.687950252103
# 20                              XINGHUA PRIMARY SCHOOL  103.890472887906
# 21                                QIHUA PRIMARY SCHOOL  103.788339756898
# 22                       WOODLANDS RING PRIMARY SCHOOL  103.797435733144
# 23                            WOODLANDS PRIMARY SCHOOL  103.791570546509
# 24                            GREENWOOD PRIMARY SCHOOL  103.804725587384
# 25                               INNOVA PRIMARY SCHOOL  103.790607539185
# 26                            WOODGROVE PRIMARY SCHOOL  103.790604437613
# 27                            RIVERSIDE PRIMARY SCHOOL  103.801831963297
# 28                            EVERGREEN PRIMARY SCHOOL  103.794577787757
# 29                            ADMIRALTY PRIMARY SCHOOL  103.800040119743
# 30                            MARSILING PRIMARY SCHOOL  103.773643013846
# 31                              SI LING PRIMARY SCHOOL  103.786035065192
# 32                               FUCHUN PRIMARY SCHOOL  103.778192944298
# 33                            TECK WHYE PRIMARY SCHOOL  103.753291857016
# 34                          WHITE SANDS PRIMARY SCHOOL  103.960918869319
# 35                             WESTWOOD PRIMARY SCHOOL   103.70053420978
# 36                            WEST VIEW PRIMARY SCHOOL  103.760240434318
# 37                               JUYING PRIMARY SCHOOL  103.687769623983
# 38                              PIONEER PRIMARY SCHOOL  103.695003812477
# 39                           WEST GROVE PRIMARY SCHOOL  103.699286360581
# 40                          JURONG WEST PRIMARY SCHOOL  103.698803732244
# 41                             FRONTIER PRIMARY SCHOOL   103.69970173931
# 42                               RULANG PRIMARY SCHOOL  103.718457955487
# 43                               SHUQUN PRIMARY SCHOOL  103.721523713379
# 44                          CORPORATION PRIMARY SCHOOL  103.707593724342
# 45                          WEST SPRING PRIMARY SCHOOL  103.766195711835
# 46                                 QIFA PRIMARY SCHOOL  103.756743261958
# 47                   PRINCESS ELIZABETH PRIMARY SCHOOL   103.74101964471
# 48                           WELLINGTON PRIMARY SCHOOL  103.822303719094
# 49                             WATERWAY PRIMARY SCHOOL  103.918621581556
# 50                            SENG KANG PRIMARY SCHOOL  103.899767112047
# 51                        PUNGGOL GREEN PRIMARY SCHOOL  103.898801330302
# 52                         PUNGGOL COVE PRIMARY SCHOOL  103.898804620697
# 53                             LAKESIDE PRIMARY SCHOOL  103.718089546664
# 54                 PEI HWA PRESBYTERIAN PRIMARY SCHOOL  103.776106448614
# 55                          NORTH VISTA PRIMARY SCHOOL  103.895961877928
# 56                         PUNGGOL VIEW PRIMARY SCHOOL  103.905156371376
# 57                           SOUTH VIEW PRIMARY SCHOOL  103.746275846011
# 58                           BUKIT VIEW PRIMARY SCHOOL   103.75366641455
# 59                            PALM VIEW PRIMARY SCHOOL  103.891354675017
# 60                            PARK VIEW PRIMARY SCHOOL  103.939541695654
# 61                             STAMFORD PRIMARY SCHOOL  103.857453500579
# 62                               VALOUR PRIMARY SCHOOL  103.899078139493
# 63                         RIVER VALLEY PRIMARY SCHOOL  103.835815165829
# 64                         THE JAPANESE PRIMARY SCHOOL  103.965590656291
# 65                                UNITY PRIMARY SCHOOL  103.746822625758
# 66         KUO CHUAN PRESBYTERIAN PRIMARY SCHOOL (U/C)  103.854447658027
# 67                      MAYFLOWER PRIMARY SCHOOL (U/C)  103.843252803742
# 68                  SAINT HILDA'S PRIMARY SCHOOL (U/C)  103.937920511812
# 69                        ANGSANA PRIMARY SCHOOL (U/C)    103.9389409004
# 70               SAINT MARGARET'S PRIMARY SCHOOL (U/C)  103.846192524384
# 71                      FIRST TOA PAYOH PRIMARY SCHOOL  103.855529906182
# 72                           TOWNSVILLE PRIMARY SCHOOL  103.853826048327
# 73                             NEW TOWN PRIMARY SCHOOL   103.80010216304
# 74                             PEI TONG PRIMARY SCHOOL  103.767599807694
# 75                          BUKIT TIMAH PRIMARY SCHOOL  103.767243310781
# 76                       TANJONG KATONG PRIMARY SCHOOL  103.900092702031
# 77                             NGEE ANN PRIMARY SCHOOL  103.917463017497
# 78                              TEMASEK PRIMARY SCHOOL  103.945590669163
# 79                          TELOK KURAU PRIMARY SCHOOL  103.910934011337
# 80                         BLANGAH RISE PRIMARY SCHOOL  103.808628535239
# 81                            TECK GHEE PRIMARY SCHOOL  103.850957126982
# 82                              JUNYUAN PRIMARY SCHOOL  103.939220722335
# 83                            GONGSHANG PRIMARY SCHOOL  103.949115320172
# 84                          EAST SPRING PRIMARY SCHOOL  103.961676849165
# 85                              ANGSANA PRIMARY SCHOOL  103.951808105552
# 86                           CHONGZHENG PRIMARY SCHOOL  103.951399541868
# 87                             TAMPINES PRIMARY SCHOOL  103.944004684986
# 88                       TAMPINES NORTH PRIMARY SCHOOL  103.948725782833
# 89                        SAINT HILDA'S PRIMARY SCHOOL  103.937007133662
# 90                         OPERA ESTATE PRIMARY SCHOOL  103.923788259248
# 91                         NORTH SPRING PRIMARY SCHOOL  103.903202683028
# 92                          COMPASSVALE PRIMARY SCHOOL  103.897812229905
# 93                              HOUGANG PRIMARY SCHOOL  103.880805274557
# 94                             MERIDIAN PRIMARY SCHOOL  103.934889078518
# 95                               KRANJI PRIMARY SCHOOL  103.747362720939
# 96                              LIANHUA PRIMARY SCHOOL  103.754165828711
# 97                            JING SHAN PRIMARY SCHOOL  103.852132214306
# 98                           ELIAS PARK PRIMARY SCHOOL  103.945128117139
# 99                            CASUARINA PRIMARY SCHOOL  103.957020286115
# 100                     SAINT ANTHONY'S PRIMARY SCHOOL  103.749251919049
# 101                              JURONG PRIMARY SCHOOL  103.733156560251
# 102                             DAZHONG PRIMARY SCHOOL   103.74847210784
# 103                            CHANGKAT PRIMARY SCHOOL  103.952080114035
# 104                           PASIR RIS PRIMARY SCHOOL  103.962807212116
# 105              KUO CHUAN PRESBYTERIAN PRIMARY SCHOOL  103.854529246517
# 106              KUO CHUAN PRESBYTERIAN PRIMARY SCHOOL  103.855018233311
# 107                               FUHUA PRIMARY SCHOOL  103.736103745748
# 108                           GUANGYANG PRIMARY SCHOOL  103.849453239895
# 109                         BEDOK GREEN PRIMARY SCHOOL  103.937878976352
# 110                    SAINT MARGARET'S PRIMARY SCHOOL  103.881624837373
# 111                     SAINT GABRIEL'S PRIMARY SCHOOL  103.862561037707
# 112           SAINT ANTHONY'S CANOSSIAN PRIMARY SCHOOL  103.941234868202
# 113                          SPRINGDALE PRIMARY SCHOOL  103.889926221247
# 114       PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)  103.884971343143
# 115                           RADIN MAS PRIMARY SCHOOL  103.824188270373
# 116                      SENGKANG GREEN PRIMARY SCHOOL  103.875217666486
# 117                        GAN ENG SENG PRIMARY SCHOOL  103.815547410064
# 118                           SEMBAWANG PRIMARY SCHOOL  103.821042374036
# 119                           NORTHOAKS PRIMARY SCHOOL  103.814196981329
# 120                 GEYLANG METHODIST SCHOOL (PRIMARY)  103.883845744916
# 121                     ANGLO-CHINESE SCHOOL (PRIMARY)  103.835609732354
# 122               FAIRFIELD METHODIST SCHOOL (PRIMARY)  103.785438270044
# 123     MAYFLOWER PRIMARY SCHOOL (JAN 2019 - DEC 2021)  103.835805246743
# 124                           EDGEFIELD PRIMARY SCHOOL  103.907847599114
# 125                           GREENDALE PRIMARY SCHOOL   103.91233462071
# 126                             HORIZON PRIMARY SCHOOL  103.913404855665
# 127                               OASIS PRIMARY SCHOOL  103.911120600638
# 128                          NORTHSHORE PRIMARY SCHOOL  103.904416909742
# 129                            FERNVALE PRIMARY SCHOOL  103.874445458032
# 130                          FERN GREEN PRIMARY SCHOOL  103.880330305684
# 131                            CANBERRA PRIMARY SCHOOL  103.815839476605
# 132                           ENDEAVOUR PRIMARY SCHOOL  103.817436231731
# 133                       CHUA CHU KANG PRIMARY SCHOOL  103.741832917421
# 134                             CONCORD PRIMARY SCHOOL  103.736225440727
# 135                              BEACON PRIMARY SCHOOL  103.773632022975
# 136                       BUKIT PANJANG PRIMARY SCHOOL  103.769374904025
# 137                          GREENRIDGE PRIMARY SCHOOL  103.767794469258
# 138                              KEMING PRIMARY SCHOOL  103.756449399351
# 139                     BOON LAY GARDEN PRIMARY SCHOOL  103.713280889452
# 140                          ANG MO KIO PRIMARY SCHOOL  103.839630858752
# 141                            ANDERSON PRIMARY SCHOOL  103.841392081119
# 142                           RIVERVALE PRIMARY SCHOOL  103.904559511997
# 143                           NAN CHIAU PRIMARY SCHOOL  103.891180928186
# 144                        ANCHOR GREEN PRIMARY SCHOOL  103.887165375933
# 145                             PUNGGOL PRIMARY SCHOOL  103.894506933668
# 146                     HOLY INNOCENTS' PRIMARY SCHOOL  103.894114899795
# 147                               DAMAI PRIMARY SCHOOL  103.921270169613
# 148                            FENGSHAN PRIMARY SCHOOL  103.931710293058
# 149                               EUNOS PRIMARY SCHOOL  103.904541254016
# 150                    CANOSSA CATHOLIC PRIMARY SCHOOL  103.882227964852
# 151                               CEDAR PRIMARY SCHOOL   103.87562104944
# 152                           BENDEMEER PRIMARY SCHOOL  103.865404167629
# 153                      RAFFLES GIRLS' PRIMARY SCHOOL  103.806442915912
# 154                          HENRY PARK PRIMARY SCHOOL  103.784296227747
# 155                             NANYANG PRIMARY SCHOOL  103.806468059795
# 156                             NANYANG PRIMARY SCHOOL  103.807750155296
# 157                         FARRER PARK PRIMARY SCHOOL  103.850766162813
# 158                           ALEXANDRA PRIMARY SCHOOL  103.824424680531
# 159                          QUEENSTOWN PRIMARY SCHOOL  103.807548617332
# 160                            CLEMENTI PRIMARY SCHOOL  103.763144493687
# 161                             NAN HUA PRIMARY SCHOOL  103.761095065761
# 162                          CANTONMENT PRIMARY SCHOOL  103.839962631748
# 163  LEARNING STUDIO BY ZENITANT (ZHONGHUA PRIMARY ...  103.869712517383
# 164            SHG STUDENT CARE (YUMIN PRIMARY SCHOOL)  103.950551091373
# 165    YMCA STUDENT CARE CENTRE @ OASIS PRIMARY SCHOOL  103.910896590133
# 166  COMMIT LEARNING SCHOOLHOUSE @ PEIYING PRIMARY ...  103.830143209875
# 167  TRI-LOVE STUDENT CARE @ NORTH VIEW PRIMARY SCHOOL  103.848254983853
# 168  WHEE!CANOPUS STUDENT CARE @ HUAMIN PRIMARY SCHOOL  103.844209671353
# 169  AVONDALE GRAMMAR SCHOOL (PRIMARY & MIDDLE YEAR...  103.814930809739
# 170          SHG STUDENT CARE (XINGNAN PRIMARY SCHOOL)  103.687588478681
# 171  POWERLIFE STUDENT SERVICES @ QIHUA PRIMARY SCHOOL  103.788339762066
# 172  COMMIT LEARNING SCHOOLHOUSE @ WOODLANDS PRIMAR...  103.791791282236
# 173        SHG STUDENT CARE (GREENWOOD PRIMARY SCHOOL)  103.804515180606
# 174  COMMIT LEARNING SCHOOLHOUSE @ WOODGROVE PRIMAR...   103.79023031392
# 175  MERCU STUDENT CARE CENTRE @ RIVERSIDE PRIMARY ...  103.801889031334
# 176    THE LEARNING HARBOUR @ ADMIRALTY PRIMARY SCHOOL  103.800213682734
# 177           SHG STUDENT CARE (FUCHUN PRIMARY SCHOOL)  103.778175192579
# 178        SHG STUDENT CARE (TECK WHYE PRIMARY SCHOOL)  103.753924558586
# 179  LEARNING LEAP PTE LTD (WHITE SANDS PRIMARY SCH...  103.960861814678
# 180  WHEE!CANOPUS STUDENT CARE @ NORTHOAKS PRIMARY ...  103.813688476692
# 181  WHEE!CANOPUS STUDENT CARE @ LAKESIDE PRIMARY S...  103.718096899655
# 182  WHEE!CANOPUS STUDENT CARE @ JUNYUAN PRIMARY SC...  103.939327626661
# 183  WHEE!CANOPUS STUDENT CARE @ EDGEFIELD PRIMARY ...  103.907430523653
# 184  BIG HEART STUDENT CARE (WEST VIEW PRIMARY SCHOOL)  103.760273432258
# 185    LEARNING LEAP PTE LTD (FRONTIER PRIMARY SCHOOL)  103.699682818103
# 186  AMP-MERCU STUDENT CARE CENTRE @ QIFA PRIMARY S...  103.756629101811
# 187  BIG HEART STUDENT CARE (PRINCESS ELIZABETH PRI...  103.740719208011
# 188  LEARNING LEAP PTE LTD (PUNGGOL GREEN PRIMARY S...  103.898794262307
# 189  KNOWLEDGE PARK EDUCARE PTE LTD (PUNGGOL COVE P...   103.89890448429
# 190          AFTERSCHOOL @ RIVER VALLEY PRIMARY SCHOOL  103.836018941571
# 191    LEARNING LEAP PTE LTD (PEI TONG PRIMARY SCHOOL)  103.767438999533
# 192           AFTERSCHOOL @ BUKIT TIMAH PRIMARY SCHOOL  103.766855344779
# 193                        THE JAPANESE PRIMARY SCHOOL  103.769354697383
# 194        AFTERSCHOOL @ TANJONG KATONG PRIMARY SCHOOL  103.899999965407
# 195     SHG STUDENT CARE (BLANGAH RISE PRIMARY SCHOOL)   103.80861316604
# 196  COMMIT LEARNING SCHOOLHOUSE @ GONGSHANG PRIMAR...  103.949144797277
# 197  BIG HEART STUDENT CARE (CHONGZHENG PRIMARY SCH...  103.951317297552
# 198  AMP-MERCU STUDENT CARE CENTRE @ TAMPINES PRIMA...  103.943573098509
# 199  BIG HEART STUDENT CARE (TAMPINES NORTH PRIMARY...  103.948768900518
# 200  LEARNING STUDIO EDUCARE @ CHANGKAT PRIMARY SCHOOL  103.952273949753
# 201        SHG STUDENT CARE (MAYFLOWER PRIMARY SCHOOL)  103.843165756947
# 202    BIG HEART STUDENT CARE (CONCORD PRIMARY SCHOOL)  103.736554295636
# 203  AMP-MERCU STUDENT CARE CENTRE @ FUHUA PRIMARY ...  103.736089481883
# 204      BIG HEART STUDENT CARE (CEDAR PRIMARY SCHOOL)   103.87562006259
# 205  BIG HEART STUDENT CARE (BOON LAY GARDEN PRIMAR...  103.712858381937
# 206        SHG STUDENT CARE (BENDEMEER PRIMARY SCHOOL)  103.865351336085
# 207  KNOWLEDGE PARK EDUCARE PTE LTE (OPERA ESTATE P...  103.923752668632
# 208            AFTERSCHOOL @ ELIAS PARK PRIMARY SCHOOL  103.945289416873
# 209  COMMIT LEARNING SCHOOLHOUSE @ CATHOLIC HIGH SC...  103.844210670766
# 210          SINGAPORE CHINESE GIRLS' SCHOOL (PRIMARY)  103.827744749548
# 211        MOE KINDERGARTEN @ NORTHOAKS PRIMARY SCHOOL  103.813722636936
# 115  1.27495823622634
# 116  1.39284606680477
# 117  1.28559516494962
# 118   1.4450737155262
# 119  1.45660782030102
# 120  1.31759126757284
# 121  1.31837054523521
# 122  1.30054082453424
# 123  1.37614621670476
# 124  1.40009139510996
# 125  1.39648195114256
# 126    1.399550034492
# 127  1.40462413200793
# 128  1.41813803336667
# 129  1.39030227963797
# 130  1.39726966050479
# 131  1.45130467584562
# 132  1.45403837499301
# 133  1.37775890093367
# 134  1.38000806197242
# 135  1.38394936211823
# 136  1.37362179302436
# 137   1.3858892193692
# 138  1.34552849960874
# 139  1.34317853793318
# 140  1.36932176584608
# 141  1.38426429436736
# 142  1.39340997767762
# 143  1.39221149906592
# 144  1.39036998654612
# 145  1.37779451191095
# 146  1.36693830877349
# 147  1.33546106800406
# 148  1.32980598760785
# 149  1.32447629876368
# 150  1.32664424544839
# 151   1.3355885014312
# 152  1.32181250780475
# 153   1.3294042600012
# 154  1.31667646178347
# 155  1.32111548993736
# 156  1.32084749904532
# 157  1.31236856978581
# 158  1.29133439161334
# 159  1.29559365009015
# 160  1.31506321827875
# 161  1.31920159956387
# 162  1.27547252623201
# 163  1.36026072476019
# 164  1.35131569890862
# 165   1.4044595121197
# 166  1.41741627551251
# 167  1.42752326549687
# 168  1.42695886300879
# 169  1.29723259722684
# 170  1.34270639669225
# 171  1.44203596557592
# 172  1.43658270720199
# 173   1.4401104867196
# 174  1.43273620725049
# 175  1.44700426493785
# 176  1.44254963931583
# 177  1.43063975763573
# 178  1.38388660469396
# 179  1.36563610941695
# 180  1.45662379586093
# 181  1.33837569571569
# 182  1.34787050871599
# 183  1.40029783011552
# 184  1.38378546546228
# 185   1.3366431119298
# 186   1.3132658326807
# 187  1.34919098857585
# 188  1.40172590450528
# 189  1.41158455562454
# 190  1.29418347842837
# 191  1.31666529308968
# 192   1.3377498622588
# 193   1.3002726804131
# 194  1.30498489044822
# 195  1.27614522920998
# 196  1.35711606790292
# 197  1.35061130568554
# 198   1.3504863946694
# 199  1.36048786025607
# 200  1.33997334692002
# 201  1.37639873282244
# 202  1.38026516111464
# 203  1.33659726465816
# 204  1.33566084356265
# 205  1.34284013791617
# 206  1.32220848530291
# 207  1.31996876377748
# 208  1.37505696315817
# 209  1.35438878373608
# 210  1.32080725235992
# 211  1.45668315343519
# 212  1.30100441916733
# 213  1.34506349843091
# 214  1.37820062547641

# %%
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('(', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace(')', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('AFTERSCHOOL @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('AMP-MERCU STUDENT CARE CENTRE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('BIG HEART STUDENT CARE ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('COMMIT LEARNING SCHOOLHOUSE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('KNOWLEDGE PARK EDUCARE PTE LTD ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('LEARNING LEAP PTE LTD ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('LEARNING STUDIO BY ZENITANT ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('LEARNING STUDIO EDUCARE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('MERCU STUDENT CARE CENTRE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('MOE KINDERGARTEN @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('POWERLIFE STUDENT SERVICES @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('SHG STUDENT CARE ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('THE LEARNING HARBOUR @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('TRI-LOVE STUDENT CARE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('THE LEARNING HARBOUR @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('WHEE!CANOPUS STUDENT CARE @ ', '')
pri_sch['primary_school'] = pri_sch['primary_school'].str.replace('YMCA STUDENT CARE CENTRE @ ', '')

# %%
pri_sch.drop_duplicates(subset='primary_school', inplace=True)

# %%
pri_sch.to_csv('../datasets/amenities/pri_sch_cleaned.csv', index=False)

# %% [markdown]
# ## Scraping Sec Sch coordinates

# %%
get_amenities('secondary school', 15, 'df_sec_sch', 'secondary_school')
# Out:
# Retrieved Page1 for secondary school Coordinates
# Retrieved Page2 for secondary school Coordinates
# Retrieved Page3 for secondary school Coordinates
# Retrieved Page4 for secondary school Coordinates
# Retrieved Page5 for secondary school Coordinates
# Retrieved Page6 for secondary school Coordinates
# Retrieved Page7 for secondary school Coordinates
# Retrieved Page8 for secondary school Coordinates
# Retrieved Page9 for secondary school Coordinates
# Retrieved Page10 for secondary school Coordinates
# Retrieved Page11 for secondary school Coordinates
# Retrieved Page12 for secondary school Coordinates
# Retrieved Page13 for secondary school Coordinates
# Retrieved Page14 for secondary school Coordinates
# Retrieved Page15 for secondary school Coordinates
#                                    secondary school         longitude  \
# 0                         ZHONGHUA SECONDARY SCHOOL  103.869430481414
# 1                         ZHENGHUA SECONDARY SCHOOL  103.765510638527
# 2                           YUYING SECONDARY SCHOOL  103.890194755287
# 3                      YUSOF ISHAK SECONDARY SCHOOL  103.760032628302
# 4                            YUHUA SECONDARY SCHOOL  103.722687235839
# 5                       YUAN CHING SECONDARY SCHOOL   103.72089870437
# 6                           JURONG SECONDARY SCHOOL  103.723952961648
# 7                           OUTRAM SECONDARY SCHOOL  103.837127264403
# 8                      YISHUN TOWN SECONDARY SCHOOL  103.838094226361
# 9                      ORCHID PARK SECONDARY SCHOOL  103.837859241343
# 10                          YISHUN SECONDARY SCHOOL  103.828764316679
# 11                       NORTHLAND SECONDARY SCHOOL  103.840104687784
# 12                     NORTHBROOKS SECONDARY SCHOOL  103.845147332528
# 101  1.39614083952009
# 102  1.37396126564931
# 103  1.33995415587811
# 104  1.33692798510393
# 105  1.33451947288431
# 106  1.30705061123433
# 107  1.33375800216334
# 108  1.28578413756164
# 109  1.30022271592188
# 110  1.31764900474601
# 111  1.34217479932295
# 112  1.30163374395823
# 113  1.32434843114787
# 114  1.35166667056342
# 115  1.38652129134849

# %% [markdown]
# ## Scraping Mall coordinates

# %% [markdown]
# The OneMap API doesn't seem to return all the shopping malls in Singapore when calling it. Instead, we will scrape the names of the shopping malls from [Wikipedia](https://en.wikipedia.org/wiki/List_of_shopping_malls_in_Singapore) using BeautifulSoup. The Wiki link has a list of 171 shopping malls as of August 2020.

# %%
from bs4 import BeautifulSoup

# %%
# get url
url = 'https://en.wikipedia.org/wiki/List_of_shopping_malls_in_Singapore'
res = requests.get(url)

# create soup object
soup = BeautifulSoup(res.content)

# create a list to append text data
ls = []

for object in soup.find_all('ul'):
    ls.append(object.text)
    
# all the shopping mall names are in element positions from 1 to 7
# we will extract by slicing it

ls = ls[1:8]

# create mall list to append all the shopping malls names
malls = []

for elem in ls:
    names = elem.split('\n')
    malls.extend(names)
    
malls
# Out:
# ['100 AM',
#  '313@Somerset',
#  'Aperia',
#  'Balestier Hill Shopping Centre',
#  'Bugis Cube',
#  'Bugis Junction',
#  'Bugis+',
#  'Capitol Piazza',
#  'Cathay Cineleisure Orchard',
#  'Clarke Quay Central',
#  'The Centrepoint',
#  'City Square Mall',
#  'City Gate Mall',
#  'CityLink Mall',
#  'Duo',
#  'Far East Plaza',
#  'Funan',
#  'Great World City',
#  'HDB Hub',
#  'Holland Village Shopping Mall',
#  'ION Orchard',
#  'Junction 8',
#  'Knightsbridge[1]',
#  'Liat Towers',
#  'Lucky Plaza',
#  'Marina Bay Sands',
#  'The Shoppes at Marina Bay Sands',
#  'Marina Bay Financial Centre Tower 3',
#  'Marina Bay Link Mall',
#  'Marina One',
#  'Marina Square',
#  'Millenia Walk',
#  'Mustafa Shopping Centre',
#  'Ngee Ann City',
#  'Orchard Central',
#  'Orchard Gateway',
#  'Orchard Plaza',
#  'Midpoint Orchard',
#  'Palais Renaissance',
#  "People's Park Centre",
#  "People's Park Complex",
#  'Plaza Singapura',
#  'PoMo',
#  'Raffles City',
#  'Scotts Square',
#  'Serangoon Plaza',
#  'Shaw House and Centre',
#  'Sim Lim Square',
#  'Singapore Shopping Centre',
#  'The South Beach',
#  'Square 2',
#  'Sunshine Plaza',
#  'Suntec City',
#  'Tanglin Mall',
#  'Tangs',
#  'Tanjong Pagar Centre',
#  'Tekka Centre',
#  'The Adelphi',
#  'The Paragon',
#  'Tiong Bahru Plaza',
#  'The Poiz[2]',
#  'Thomson Plaza',
#  'United Square',
#  'Velocity@Novena Square',
#  'Wheelock Place',
#  'Wisma Atria',
#  'Zhongshan Mall',
#  'Century Square',
#  'Tampines 1',
#  'Tampines Mall',
#  'Our Tampines Hub',
#  'Changi City Point',
#  'Downtown East',
#  'Djitsun Mall Bedok',
#  'Eastpoint Mall',
#  'Bedok Mall',
#  'Bedok Point',
#  'Paya Lebar Square',
#  'Singapore Post Centre (Singpost Centre)',
#  'Paya Lebar Quarter (PLQ)',
#  'KINEX (formerly OneKM)',
#  'Katong Shopping Centre',
#  'Roxy Square',
#  'i12 Katong',
#  'Parkway Parade',
#  'White Sands',
#  'City Plaza',
#  'Katong Square',
#  'Katong V',
#  'Kallang Wave Mall',
#  'Leisure Park Kallang',
#  'Elias Mall',
#  'Loyang Point',
#  'Jewel Changi Airport',
#  '888 Plaza',
#  'Admiralty Place',
#  'AMK Hub',
#  'Canberra Plaza',
#  'Causeway Point',
#  'Woodlands Civic Centre',
#  'Broadway Plaza',
#  'Djitsun Mall',
#  'Jubilee Square',
#  'Junction 9',
#  'Marsiling Mall',
#  'Northpoint City',
#  'Sembawang Shopping Centre',
#  'Sun Plaza',
#  'Vista Point',
#  'Wisteria Mall',
#  'Woodlands Mart',
#  'Woodlands North Plaza',
#  'Waterway Point',
#  'Compass One',
#  'Hougang Mall',
#  'Heartland Mall',
#  'NEX',
#  'Greenwich V',
#  'Hougang 1',
#  'Hougang Green Shopping Mall',
#  'myVillage At Serangoon Garden',
#  'Oasis Terraces',
#  'Punggol Plaza',
#  'Rivervale Mall',
#  'Rivervale Plaza',
#  'The Seletar Mall',
#  'Buangkok Square',
#  'The Midtown',
#  'Upper Serangoon Shopping Centre',
#  'Beauty World Centre',
#  'Beauty World Plaza',
#  'Bukit Panjang Plaza',
#  'Bukit Timah Plaza',
#  'Fajar Shopping Centre',
#  'Greenridge Shopping Centre',
#  'Hillion Mall',
#  'HillV2',
#  'Junction 10',
#  'Keat Hong Shopping Centre',
#  'Limbang Shopping Centre',
#  'Lot One',
#  'Rail Mall',
#  'Sunshine Place',
#  'Teck Whye Shopping Centre',
#  'West Mall',
#  'Yew Tee Point',
#  'Yew Tee Shopping Centre',
#  'Yew Tee Square',
#  'VivoCity',
#  'HarbourFront Centre',
#  'Alexandra Retail Centre',
#  '321 Clementi',
#  'The Clementi Mall',
#  'IMM',
#  'JCube',
#  'Jem',
#  'Westgate',
#  'Jurong Point',
#  'Pioneer Mall',
#  'The Star Vista',
#  'Alexandra Central',
#  'Anchorpoint',
#  'OD Mall',
#  'Boon Lay Shopping Centre',
#  'Grantral Mall',
#  'Fairprice Hub',
#  'Gek Poh Shopping Centre',
#  'Rochester Mall',
#  'Taman Jurong Shopping Centre',
#  'West Coast Plaza',
#  'Queensway Shopping Centre']

# %%
len(malls)
# Out:
# 171

# %% [markdown]
# With our list of malls, we can call on the OneMap API to search for the geo coordinates. During our initial search, we noted that some of the malls did not return longitudes and latitudes as their names were misspelt. We will clean them up and search again afterwards.

# %% [markdown]
# To correct the following spellings of the malls:
#
# - Knightsbridge[1] to: Knightsbridge
# - The Poiz[2] to: The Poiz
# - Velocity@Novena Square to: Velocity @ Novena Square
# - Singapore Post Centre (Singpost Centre) to: Singpost Centre
# - Paya Lebar Quarter (PLQ) to: PLQ
# - KINEX (formerly OneKM) to: KINEX

# %%
# a quick way to find and replace elements in a list, referenced from: 
# https://stackoverflow.com/questions/2582138/finding-and-replacing-elements-in-a-list

replace = {'Knightsbridge[1]': 'Knightsbridge', 'The Poiz[2]': 'The Poiz',
           'Velocity@Novena Square': 'Velocity @ Novena Square', 
           'Singapore Post Centre (Singpost Centre)': 'Singpost Centre',
           'Paya Lebar Quarter (PLQ)': 'PLQ', 'KINEX (formerly OneKM)': 'KINEX'}

replacer = replace.get
malls = [replacer(x, x) for x in malls]

# %%
# pulling long, lat of shopping malls 

count = 1
ls = []

for mall in malls:
    
    url = f'https://developers.onemap.sg/commonapi/search?searchVal={mall}&returnGeom=Y&getAddrDetails=Y'
    print(url)
    res = requests.get(url)

    # Check Status Code
    if res.status_code != 200:
        print("Error",res.status_code)
        
    else:
        print(f'Retrieving mall {count} geo coordinates')
        data = res.json()
        
        try:
            results = {'mall': data['results'][0]['BUILDING'],
                       'longitude': data['results'][0]['LONGITUDE'],
                       'latitude': data['results'][0]['LATITUDE']}
            
        except:
            results = {'mall': mall,
                       'longitude': 'NA',
                       'latitude': 'NA'}

        
    ls.append(results)
    count += 1


mall_df = pd.DataFrame(ls)
mall_df.to_csv(f'../datasets/amenities/mall.csv', index=False)
# Out:
# https://developers.onemap.sg/commonapi/search?searchVal=100 AM&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 1 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=313@Somerset&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 2 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Aperia&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 3 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Balestier Hill Shopping Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 4 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Bugis Cube&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 5 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Bugis Junction&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 6 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Bugis+&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 7 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Capitol Piazza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 8 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Cathay Cineleisure Orchard&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 9 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Clarke Quay Central&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 10 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The Centrepoint&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 11 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=City Square Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 12 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=City Gate Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 13 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=CityLink Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 14 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Duo&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 15 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Far East Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 16 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Funan&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 17 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Great World City&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 18 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=HDB Hub&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 19 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Holland Village Shopping Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 20 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=ION Orchard&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 21 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Junction 8&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 22 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Knightsbridge&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 23 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Liat Towers&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 24 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Lucky Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 25 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Marina Bay Sands&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 26 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The Shoppes at Marina Bay Sands&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 27 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Marina Bay Financial Centre Tower 3&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 28 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Marina Bay Link Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 29 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Marina One&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 30 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Marina Square&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 31 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Millenia Walk&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 32 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Mustafa Shopping Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 33 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Ngee Ann City&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 34 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Orchard Central&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 35 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Orchard Gateway&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 36 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Orchard Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 37 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Midpoint Orchard&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 38 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Palais Renaissance&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 39 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=People's Park Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 40 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=People's Park Complex&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 41 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Plaza Singapura&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 42 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=PoMo&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 43 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Raffles City&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 44 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Scotts Square&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 45 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Serangoon Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 46 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Shaw House and Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 47 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Sim Lim Square&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 48 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Singapore Shopping Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 49 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The South Beach&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 50 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Square 2&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 51 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Sunshine Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 52 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Suntec City&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 53 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Tanglin Mall&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 54 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Tangs&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 55 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Tanjong Pagar Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 56 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Tekka Centre&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 57 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The Adelphi&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 58 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The Paragon&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 59 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Tiong Bahru Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 60 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=The Poiz&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 61 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Thomson Plaza&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 62 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=United Square&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 63 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Velocity @ Novena Square&returnGeom=Y&getAddrDetails=Y
# Retrieving mall 64 geo coordinates
# https://developers.onemap.sg/commonapi/search?searchVal=Wheelock Place&returnGeom=Y&getAddrDetails=Y
# Retrieving mall